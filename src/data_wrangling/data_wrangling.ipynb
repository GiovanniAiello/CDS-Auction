# %%
import pandas as pd
import re

# Specify the file path to the dataset
dataset_path = '../../data/final_database/auctions_main.csv'
# Read the dataset
data = pd.read_csv(dataset_path)


# Function to extract numeric value from a string
def extract_numeric_value(string):
    match = re.search(r'\d+(\.\d+)?', string)
    if match:
        return float(match.group())
    return None

# Create the new columns
data['noi_absolute_value'] = data['NOI'].apply(lambda x: extract_numeric_value(x) if isinstance(x, str) else None)
data['noi_absolute_value'] = data['noi_absolute_value']*1000000

# Round the 'noi_absolute_value' to 2 decimal places
data['noi_absolute_value'] = data['noi_absolute_value'].round(2)

data['noi_direction'] = data['NOI'].apply(lambda x: -1 if isinstance(x, str) and ('to buy' in x or 'bid' in x) else (1 if isinstance(x, str) and ('to sell' in x or 'offer' in x) else 0 if isinstance(x, str) and extract_numeric_value(x) == 0 else None))

data['currency'] = data['NOI'].apply(lambda x: re.findall(r'[^\d\s]+', x)[0] if isinstance(x, str) and re.findall(r'[^\d\s]+', x) else None)
# Print the updated DataFrame
print(data[['NOI', 'noi_absolute_value', 'noi_direction', 'currency']])
# Out:
#                               NOI  noi_absolute_value  noi_direction currency
# 0             $99 million to sell        9.900000e+07            1.0        $
# 1             $45 million to sell        4.500000e+07            1.0        $
# 2             $41 million to sell        4.100000e+07            1.0        $
# 3               $20m (offer side)        2.000000e+07            1.0        $
# 4             $77 million to sell        7.700000e+07            1.0        $
# 5        $30.5 million (bid side)        3.050000e+07           -1.0        $
# 6             $66 Million to sell        6.600000e+07            1.0        $
# 7             $60 million to sell        6.000000e+07            1.0        $
# 8              $12 million to buy        1.200000e+07           -1.0        $
# 9             $608 million to buy        6.080000e+08           -1.0        $
# 10             $79 million to buy        7.900000e+07           -1.0        $
# 11            $542 million to buy        5.420000e+08           -1.0        $
# 12          $4.92 billion to sell        4.920000e+06            1.0        $
# 13          $988 million to sell.        9.880000e+08            1.0        $
# 14           €454 million to sell        4.540000e+08            1.0        €
# 15            €63 million to sell        6.300000e+07            1.0        €
# 16           €187 million to sell        1.870000e+08            1.0        €
# 17            €55 million to sell        5.500000e+07            1.0        €
# 18           €974 million to sell        9.740000e+08            1.0        €
# 19            €11 million to sell        1.100000e+07            1.0        €
# 20             $18 million to buy        1.800000e+07           -1.0        $
# 21           $8.5 million to sell        8.500000e+06            1.0        $
# 22           $765 million to sell        7.650000e+08            1.0        $
# 23             $2 million to sell        2.000000e+06            1.0        $
# 24         $77.482 million to buy        7.748200e+07           -1.0        $
# 25        $33.476 million to sell        3.347600e+07            1.0        $
# 26       $143.238 million to sell        1.432380e+08            1.0        $
# 27           $138 million to sell        1.380000e+08            1.0        $
# 28         $10.15 million to sell        1.015000e+07            1.0        $
# 29              €2 million to buy        2.000000e+06           -1.0        €
# 30                             €0        0.000000e+00            0.0        €
# 31            £11 million to sell        1.100000e+07            1.0        £
# 32                             £0        0.000000e+00            0.0        £
# 33        $290.47 million to sell        2.904700e+08            1.0        $
# 34        $12.916 million to sell        1.291600e+07            1.0        $
# 35       $128.675 million to sell        1.286750e+08            1.0        $
# 36            $40 million to sell        4.000000e+07            1.0        $
# 37                             €0        0.000000e+00            0.0        €
# 38             $40 million to buy        4.000000e+07           -1.0        $
# 39             $24 million to buy        2.400000e+07           -1.0        $
# 40        $98.738 million to sell        9.873800e+07            1.0        $
# 41       $130.632 million to sell        1.306320e+08            1.0        $
# 42         $8.585 million to sell        8.585000e+06            1.0        $
# 43        €95.245 million to sell        9.524500e+07            1.0        €
# 44       $234.247 million to sell        2.342470e+08            1.0        $
# 45          $49.2 million to sell        4.920000e+07            1.0        $
# 46            $40 million to sell        4.000000e+07            1.0        $
# 47        $115.05 million to sell        1.150500e+08            1.0        $
# 48       $889.557 million to sell        8.895570e+08            1.0        $
# 49            $10 million to sell        1.000000e+07            1.0        $
# 50       $117.583 million to sell        1.175830e+08            1.0        $
# 51            $20 million to sell        2.000000e+07            1.0        $
# 52        $234.924 million to buy        2.349240e+08           -1.0        $
# 53                             €0        0.000000e+00            0.0        €
# 54             $7 million to sell        7.000000e+06            1.0        $
# 55             $16 million to buy        1.600000e+07           -1.0        $
# 56           $809 million to sell        8.090000e+08            1.0        $
# 57         $143.9 million to sell        1.439000e+08            1.0        $
# 58        $529.098 million to buy        5.290980e+08           -1.0        $
# 59            $46 million to sell        4.600000e+07            1.0        $
# 60             $28 million to buy        2.800000e+07           -1.0        $
# 61       $179.677 million to sell        1.796770e+08            1.0        $
# 62            $40 million to sell        4.000000e+07            1.0        $
# 63            $17 million to sell        1.700000e+07            1.0        $
# 64            $13 million to sell        1.300000e+07            1.0        $
# 65            $37 million to sell        3.700000e+07            1.0        $
# 66             $62 million to buy        6.200000e+07           -1.0        $
# 67            $19 million to sell        1.900000e+07            1.0        $
# 68       $172.528 million to sell        1.725280e+08            1.0        $
# 69            $70 million to sell        7.000000e+07            1.0        $
# 70        €145.334 million to buy        1.453340e+08           -1.0        €
# 71         €27.67 million to sell        2.767000e+07            1.0        €
# 72                             £0        0.000000e+00            0.0        £
# 73        €80.967 million to sell        8.096700e+07            1.0        €
# 74       €220.669 million to sell        2.206690e+08            1.0        €
# 75       €147.568 million to sell        1.475680e+08            1.0        €
# 76            $23 million to sell        2.300000e+07            1.0        $
# 77        $728.98 million to sell        7.289800e+08            1.0        $
# 78        €57.495 million to sell        5.749500e+07            1.0        €
# 79       €246.243 million to sell        2.462430e+08            1.0        €
# 80       $135.645 million to sell        1.356450e+08            1.0        $
# 81        $182.255 million to buy        1.822550e+08           -1.0        $
# 82         $90.425 million to buy        9.042500e+07           -1.0        $
# 83   JPY 17,020.6 million to sell        1.700000e+07            1.0      JPY
# 84              £0 million to buy        0.000000e+00           -1.0        £
# 85        JPY 300 million to sell        3.000000e+08            1.0      JPY
# 86    USD 300.098 million to sell        3.000980e+08            1.0      USD
# 87    EUR 235.263 million to sell        2.352630e+08            1.0      EUR
# 88                          EUR 0        0.000000e+00            0.0      EUR
# 89           USD 5 million to buy        5.000000e+06           -1.0      USD
# 90      JPY 21200 million to sell        2.120000e+10            1.0      JPY
# 91     EUR 104.05 million to sell        1.040500e+08            1.0      EUR
# 92       EUR 23.5 million to sell        2.350000e+07            1.0      EUR
# 93       EUR 22.55 million to buy        2.255000e+07           -1.0      EUR
# 94      EUR 11.25 million to sell        1.125000e+07            1.0      EUR
# 95         EUR 30 million to sell        3.000000e+07            1.0      EUR
# 96    USD 407.905 million to sell        4.079050e+08            1.0      USD
# 97         EUR 7.9 million to buy        7.900000e+06           -1.0      EUR
# 98        EUR 2.05 million to buy        2.050000e+06           -1.0      EUR
# 99       EUR 22.65 million to buy        2.265000e+07           -1.0      EUR
# 100         EUR 31 million to buy        3.100000e+07           -1.0      EUR
# 101      EUR 12.8 million to sell        1.280000e+07            1.0      EUR
# 102       EUR 5.15 million to buy        5.150000e+06           -1.0      EUR
# 103                          None                 NaN            NaN     None
# 104         EUR 3 million to sell        3.000000e+06            1.0      EUR
# 105         EUR 28 million to buy        2.800000e+07           -1.0      EUR
# 106          EUR 3 million to buy        3.000000e+06           -1.0      EUR
# 107         EUR 25 million to buy        2.500000e+07           -1.0      EUR
# 108      EUR 11.6 million to sell        1.160000e+07            1.0      EUR
# 109         EUR 10 million to buy        1.000000e+07           -1.0      EUR
# 110      EUR 11.5 million to sell        1.150000e+07            1.0      EUR
# 111                          None                 NaN            NaN     None
# 112         EUR 5 million to sell        5.000000e+06            1.0      EUR
# 113                          None                 NaN            NaN     None
# 114         EUR 10 million to buy        1.000000e+07           -1.0      EUR
# 115      JPY 2400 million to sell        2.400000e+09            1.0      JPY
# 116                          None                 NaN            NaN     None
# 117     USD 61.156 million to buy        6.115600e+07           -1.0      USD
# 118     EUR 66.75 million to sell        6.675000e+07            1.0      EUR
# 119   USD 375.588 million to sell        3.755880e+08            1.0      USD
# 120    USD 119.485 million to buy        1.194850e+08           -1.0      USD
# 121        13.649 million to sell        1.364900e+07            1.0        .
# 122       EUR 17.5 million to buy        1.750000e+07           -1.0      EUR
# 123         EUR 11 million to buy        1.100000e+07           -1.0      EUR
# 124   USD 226.369 million to sell        2.263690e+08            1.0      USD
# 125     EUR 291.6 million to sell        2.916000e+08            1.0      EUR
# 126      JPY 1800 million to sell        1.800000e+09            1.0      JPY
# 127              5 million to buy        5.000000e+06           -1.0  million
# 128     EUR 123.3 million to sell        1.233000e+08            1.0      EUR
# 129              3 million to buy        3.000000e+06           -1.0  million
# 130            39 million to sell        3.900000e+07            1.0  million
# 131              1 million to buy        1.000000e+06           -1.0  million
# 132     USD 36.05 million to sell        3.605000e+07            1.0      USD
# 133    USD 16.165 million to sell        1.616500e+07            1.0      USD
# 134     USD 29.032 million to buy        2.903200e+07           -1.0      USD
# 135       EUR 18.5 million to buy        1.850000e+07           -1.0      EUR
# 136    USD 41.185 million to sell        4.118500e+07            1.0      USD
# 137       USD 6.25 million to buy        6.250000e+06           -1.0      USD
# 138          EUR 2 million to buy        2.000000e+06           -1.0      EUR
# 139     EUR 11.65 million to sell        1.165000e+07            1.0      EUR
# 140        EUR 13 million to sell        1.300000e+07            1.0      EUR
# 141              2 million to buy        2.000000e+06           -1.0  million
# 142              2 million to buy        2.000000e+06           -1.0  million
# 143         EUR 21 million to buy        2.100000e+07           -1.0      EUR
# 144       EUR 12.7 million to buy        1.270000e+07           -1.0      EUR
# 145       EUR 7.5 million to sell        7.500000e+06            1.0      EUR
# 146        EUR 10 million to sell        1.000000e+07            1.0      EUR
# 147      USD 72.9 million to sell        7.290000e+07            1.0      USD
# 148                     0 million        0.000000e+00            0.0  million
# 149     EUR 103.45 million to buy        1.034500e+08           -1.0      EUR
# 150        USD 0.2 million to buy        2.000000e+05           -1.0      USD
# 151                     0 Million        0.000000e+00            0.0  Million
# 152     USD 23.944 million to buy        2.394400e+07           -1.0      USD
# 153        USD 141 million to buy        1.410000e+08           -1.0      USD
# 154     USD 70.75 million to sell        7.075000e+07            1.0      USD
# 155        EUR 0.5 million to buy        5.000000e+05           -1.0      EUR
# 156      USD 96.03 million to buy        9.603000e+07           -1.0      USD
# 157    USD 49.094 million to sell        4.909400e+07            1.0      USD
# 158             37 million to buy        3.700000e+07           -1.0  million
# 159    USD 59.318 million to sell        5.931800e+07            1.0      USD
# 160    USD 46.833 million to sell        4.683300e+07            1.0      USD
# 161    USD 47.638 million to sell        4.763800e+07            1.0      USD
# 162     USD 15.45 million to sell        1.545000e+07            1.0      USD
# 163     EUR 329.4 million to sell        3.294000e+08            1.0      EUR
# 164      USD 1.23 million to sell        1.230000e+06            1.0      USD
# 165        65.267 million to sell        6.526700e+07            1.0        .
# 166     EUR 69.25 million to sell        6.925000e+07            1.0      EUR
# 167      EUR 34.1 million to sell        3.410000e+07            1.0      EUR
# 168                 EUR 0 million        0.000000e+00            0.0      EUR
# 169      EUR 5.55 million to sell        5.550000e+06            1.0      EUR
# 170      EUR 86.2 million to sell        8.620000e+07            1.0      EUR
# 171      USD 8.265 million to buy        8.265000e+06           -1.0      USD
# 172      EUR 56.9 million to sell        5.690000e+07            1.0      EUR
# 173   USD 181.982 million to sell        1.819820e+08            1.0      USD
# 174                           0.0        0.000000e+00            0.0        .
# 175              0 million to buy        0.000000e+00           -1.0  million
# 176    USD 63.805 million to sell        6.380500e+07            1.0      USD
# 177      USD 3.84 million to sell        3.840000e+06            1.0      USD
# 178     EUR 69.25 million to sell        6.925000e+07            1.0      EUR
# 179      EUR 34.1 million to sell        3.410000e+07            1.0      EUR
# 180                 EUR 0 million        0.000000e+00            0.0      EUR
# 181      EUR 5.55 million to sell        5.550000e+06            1.0      EUR
# 182       EUR 2.95 million to buy        2.950000e+06           -1.0      EUR
# 183         EUR 10 million to buy        1.000000e+07           -1.0      EUR
# 184                 EUR 0 million        0.000000e+00            0.0      EUR
# 185          USD 0 million to buy        0.000000e+00           -1.0      USD
# 186    USD 81.172 million to sell        8.117200e+07            1.0      USD
# 187      EUR 55.05 million to buy        5.505000e+07           -1.0      EUR
# 188       EUR 5.5 million to sell        5.500000e+06            1.0      EUR
# 189    USD 105.133 million to buy        1.051330e+08           -1.0      USD
# 190    USD 105.92 million to sell        1.059200e+08            1.0      USD
# 191       USD 6.3 million to sell        6.300000e+06            1.0      USD
# 192   USD 162.351 million to sell        1.623510e+08            1.0      USD
# 193          EUR 0 million to buy        0.000000e+00           -1.0      EUR
# 194                           NaN                 NaN            NaN     None
# 195                           NaN                 NaN            NaN     None
# 196       EUR 37.4 million to buy        3.740000e+07           -1.0      EUR
# 197     USD 44.936 million to buy        4.493600e+07           -1.0      USD
# 198    USD 47.397 million to sell        4.739700e+07            1.0      USD
# 199      USD 20.8 million to sell        2.080000e+07            1.0      USD
# 200     USD 68.204 million to buy        6.820400e+07           -1.0      USD
# 201      EUR 58.8 million to sell        5.880000e+07            1.0      EUR
# 202        167.15 million to sell        1.671500e+08            1.0        .
# 203    USD 93.312 million to sell        9.331200e+07            1.0      USD
# 204      EUR 14.4 million to sell        1.440000e+07            1.0      EUR
# 205          EUR 0 million to buy        0.000000e+00           -1.0      EUR
# 206        EUR 8.4 million to buy        8.400000e+06           -1.0      EUR
# 207     EUR 171.7 million to sell        1.717000e+08            1.0      EUR
# 208   USD 180.986 million to sell        1.809860e+08            1.0      USD
# 209    USD 62.563 million to sell        6.256300e+07            1.0      USD
# 210     USD 108.7 million to sell        1.087000e+08            1.0      USD
# 211   USD 192.773 million to sell        1.927730e+08            1.0      USD
# 212   USD 116.631 million to sell        1.166310e+08            1.0      USD
# 213     USD 27.282 million to buy        2.728200e+07           -1.0      USD
# 214   USD 176.585 million to sell        1.765850e+08            1.0      USD
# 215   USD 178.711 million to sell        1.787110e+08            1.0      USD
# 216          USD 0 million to buy        0.000000e+00           -1.0      USD
# 217   USD 352.117 million to sell        3.521170e+08            1.0      USD
# 218   USD 310.886 million to sell        3.108860e+08            1.0      USD
# 219   USD 111.525 million to sell        1.115250e+08            1.0      USD
# 220    USD 69.043 million to sell        6.904300e+07            1.0      USD
# 221      EUR 50.1 million to sell        5.010000e+07            1.0      EUR
# 222   USD 265.626 million to sell        2.656260e+08            1.0      USD
# 223       EUR 4.4 million to sell        4.400000e+06            1.0      EUR
# 224   USD 111.585 million to sell        1.115850e+08            1.0      USD
# 225      GBP 11.5 million to sell        1.150000e+07            1.0      GBP
# 226     GBP 47.75 million to sell        4.775000e+07            1.0      GBP
# 227           7.8 million to sell        7.800000e+06            1.0        .
# 228           43.3 million to buy        4.330000e+07           -1.0        .
# 229    USD 106.048 million to buy        1.060480e+08           -1.0      USD
# 230      USD 502.4 million to buy        5.024000e+08           -1.0      USD
# 231         USD 41 million to buy        4.100000e+07           -1.0      USD
# 232      USD 44.7 million to sell        4.470000e+07            1.0      USD

# %%
import os
import pandas as pd

database_path = '../../data/raw_auction_csv'

# Iterate over each row of the dataset
for index, row in data.iterrows():
    identifier = row['identifier']
    
    # Find the file based on the identifier
    matching_files = [file for file in os.listdir(database_path) if file.endswith('.csv') and "Final Results" in file and identifier in file]
    
    if matching_files:
        file_path = os.path.join(database_path, matching_files[0])
        df = pd.read_csv(file_path, header=None)
        
        # Check if the first line is "Relevant Currency"
        if df.iloc[0, 0] == "Relevant Currency":
            # Update the 'currency' column with the value from the second line
            data.loc[data['identifier'] == identifier, 'currency'] = df.iloc[1, 0]

# Print the updated DataFrame
print(data[['identifier', 'currency']])
# Out:
#                                      identifier currency
# 0                           20051104_delphi_CDS        $
# 1                          20060117_calpine_CDS        $
# 2                 20060331_dana_corporation_CDS        $
# 3                      20061128_dura_senior_CDS        $
# 4                20061128_dura_subordinated_CDS        $
# 5                   20071023_movie_gallery_LCDS        $
# 6                           20080219_quebcr_CDS        $
# 7                           20081002_tembec_CDS        $
# 8           20081006_famefrmc_Fannie-Mae-Senior        $
# 9     20081006_famefrmc_Fannie-Mae-Subordinated        $
# 10         20081006_famefrmc_Freddie-Mac-Senior        $
# 11   20081006_famefrmc_Freddie-Mac-Subordinated        $
# 12                          20081010_lehbro_CDS        $
# 13                          20081023_washmu_CDS        $
# 14                       20081104_landsb_Senior        €
# 15                 20081104_landsb_Subordinated        €
# 16                       20081105_glitni_Senior        €
# 17                 20081105_glitni_Subordinated        €
# 18                       20081106_kaupth_Senior        €
# 19                 20081106_kaupth_Subordinated        €
# 20                          20081209_masoni_CDS        $
# 21                          20081217_hawtel_CDS        $
# 22                          20090106_tribco_CDS        $
# 23                         20090106_tribco_LCDS        $
# 24                          20090114_ecuado_CDS        $
# 25                          20090203_equstr_CDS        $
# 26                          20090203_lyodel_CDS        $
# 27                         20090203_lyodel_LCDS        $
# 28                          20090203_millen_CDS        $
# 29                     20090205_sanitc_1st-Lien        €
# 30                     20090205_sanitc_2nd-Lien        €
# 31                         20090209_br_1st-Lien        £
# 32                         20090209_br_2nd-Lien        £
# 33                          20090210_norcor_CDS        $
# 34                          20090210_norltd_CDS        $
# 35                          20090219_smurfs_CDS        $
# 36                         20090219_smurfs_LCDS        $
# 37                         20090226_fereti_LCDS        €
# 38                         20090309_aleris_LCDS        $
# 39                          20090331_stncas_CDS        $
# 40                          20090414_chmtra_CDS        $
# 41                          20090414_grtlak_CDS        $
# 42                           20090415_rouse_CDS        $
# 43                          20090416_lyobas_CDS        €
# 44                          20090417_abitbi_CDS        $
# 45                          20090421_chacom_CDS        $
# 46                         20090421_chacom_LCDS        $
# 47                          20090422_capmrk_CDS        $
# 48                          20090423_idearc_CDS        $
# 49                         20090423_idearc_LCDS        $
# 50                          20090512_bowatr_CDS      USD
# 51                         20090513_gegrpr_LCDS        $
# 52                          20090527_syncra_CDS        $
# 53                         20090528_edscha_LCDS        €
# 54                          20090609_hliop_LCDS        $
# 55                         20090610_geguco_LCDS        $
# 56                          20090610_jscbta_CDS        $
# 57                          20090611_rhdcor_CDS      USD
# 58                          20090612_genmtr_CDS        $
# 59                         20090612_genmtr_LCDS        $
# 60                          20090618_jscali_CDS        $
# 61                          20090623_viston_CDS        $
# 62                         20090623_viston_LCDS        $
# 63                         20090624_dexest_LCDS        $
# 64                         20090624_dexwst_LCDS        $
# 65                         20090624_rhdltd_LCDS        $
# 66                          20090709_sixflg_CDS      USD
# 67                         20090709_sixflg_LCDS        $
# 68                          20090721_leacor_CDS        $
# 69                         20090721_leacor_LCDS        $
# 70                       20090730_brabin_Senior      EUR
# 71                 20090730_brabin_Subordinated        €
# 72                         20091008_sspflt_LCDS        £
# 73     20091022_thmbrd_2.5-year-maturity-bucket        €
# 74       20091022_thmbrd_5-year-maturity-bucket      EUR
# 75     20091022_thmbrd_7.5-year-maturity-bucket        €
# 76                         20091110_mgminc_LCDS        $
# 77                          20091120_citgrp_CDS        $
# 78                          20091210_thomsn_CDS      EUR
# 79             20091215_hellas_CDS-Subordinated        €
# 80                          20091216_nafukr_CDS      USD
# 81                            20100107_fgic_CDS      USD
# 82                           20100218_cemex_CDS      USD
# 83                           20100325_aiful_CDS      JPY
# 84                   20100415_carstn_LCDS-LIEN1        £
# 85                          20100422_jalcor_CDS      JPY
# 86                   20100604_ABK-AssurCorp_CDS      USD
# 87                     20100715_TRUVO-SubCo_CDS      EUR
# 88                   20100909_WorldDir-B07_LCDS      EUR
# 89                           20100921_BOSG_LCDS      USD
# 90                          20101028_TAKFUJ_CDS      JPY
# 91       20101209_ANGBKL_CDS-SNR-or-SUB-Bucket1      EUR
# 92           20101209_ANGBKL_CDS-Senior-Bucket2      EUR
# 93           20101209_ANGBKL_CDS-Senior-Bucket3      EUR
# 94     20101209_ANGBKL_CDS-Subordinated-Bucket2      EUR
# 95     20101209_ANGBKL_CDS-Subordinated-Bucket3      EUR
# 96                             20101210_ABK_CDS      USD
# 97       20110202_ANGBKL2_CDS-25-years-maturity      EUR
# 98                      20110630_AIB_CDS-Senior      EUR
# 99                20110630_AIB_CDS-Subordinated      EUR
# 100        20110728_BKIR_CDS-SNR-or-SUB-Bucket1      EUR
# 101            20110728_BKIR_CDS-Senior-Bucket2      EUR
# 102            20110728_BKIR_CDS-Senior-Bucket3      EUR
# 103            20110728_BKIR_CDS-Senior-Bucket6      EUR
# 104      20110728_BKIR_CDS-Subordinated-Bucket2      EUR
# 105      20110728_BKIR_CDS-Subordinated-Bucket3      EUR
# 106      20110728_BKIR_CDS-Subordinated-Bucket6      EUR
# 107            20110729_IPBS_CDS-Senior-Bucket1      EUR
# 108            20110729_IPBS_CDS-Senior-Bucket2      EUR
# 109            20110729_IPBS_CDS-Senior-Bucket3      EUR
# 110      20110729_IPBS_CDS-Subordinated-Bucket1      EUR
# 111      20110729_IPBS_CDS-Subordinated-Bucket2      EUR
# 112      20110729_IPBS_CDS-Subordinated-Bucket3      EUR
# 113          20111005_IPBS2_CDS-Senior-Bucket-1      EUR
# 114          20111005_IPBS2_CDS-Senior-Bucket-2      EUR
# 115                            20111109_JVC_CDS      JPY
# 116                        20111123_PANRIC_LCDS      EUR
# 117                         20111129_DYNHLD_CDS      USD
# 118                          20111209_SPGIM_CDS      EUR
# 119                            20111213_PMI_CDS      USD
# 120                            20111215_AMR_CDS      USD
# 121                      20120117_Seat-A05_LCDS      EUR
# 122                 20120202_NRAMC_CDS-Bucket-1      EUR
# 123                 20120202_NRAMC_CDS-Bucket-2      EUR
# 124                             20120222_EK_CDS      USD
# 125                         20120319_GREECE_CDS      EUR
# 126                  20120322_HITACH-Elpida_CDS      JPY
# 127                         20120328_FCGIA_LCDS  million
# 128                         20120329_ERCIFT_CDS      EUR
# 129                  20120426_HAWKER-Acqui_LCDS      USD
# 130            20120502_ELCDS-Eircom_LCDS-LIEN1  million
# 131            20120502_ELCDS-Eircom_LCDS-LIEN2      EUR
# 132                           20120509_SIFO_CDS      USD
# 133                         20120530_HTNMIF_CDS      USD
# 134                     20120606_GM-ResCLLC_CDS      USD
# 135              20121115_ELCDS-Yell_LCDS-LIEN1      EUR
# 136                            20121206_OSG_CDS      USD
# 137                20130116_EIX-EdMisEnergy_CDS      USD
# 138                      20130131_PJHOLDCO_LCDS      EUR
# 139              20130404_SNSBNK_CDS-SNR-or-SUB      EUR
# 140     20130404_SNSBNK_CDS-SNR-or-SUB-Bucket-1      EUR
# 141                          20130424_DXMI_LCDS  million
# 142                          20130424_SPMD_LCDS  million
# 143              20130605_BANKSA_CDS-SNR-or-SUB      EUR
# 144     20130605_BANKSA_CDS-SNR-or-SUB-Bucket-1      EUR
# 145     20130605_BANKSA_CDS-SNR-or-SUB-Bucket-2      EUR
# 146     20130605_BANKSA_CDS-SNR-or-SUB-Bucket-3      EUR
# 147                         20130606_URBISA_CDS      USD
# 148                        20130806_CENGLQ_LCDS      USD
# 149                      20131009_CODSA-Fin_CDS      EUR
# 150                         20131204_OGXPET_CDS      USD
# 151                        20140521_ENERFUT_CDS  Million
# 152                        20140521_ENERGFU_CDS      USD
# 153          20140521_TXU-Texas-LCDS_LCDS-LIEN1      USD
# 154                      20140521_TXU-Texas_CDS      USD
# 155                       20140819_SOLOGRO_LCDS      EUR
# 156                         20140903_ARGENT_CDS      USD
# 157                         20150219_CESEOP_CDS      USD
# 158                        20150219_CESEOP_LCDS      USD
# 159                            20150305_RSH_CDS      USD
# 160                        20150623_SABINOI_CDS      USD
# 161                           20150917_AAHI_CDS      USD
# 162                         20151006_UKRAIN_CDS      USD
# 163                           20160114_ABNG_CDS      EUR
# 164                        20160406_PACIEXP_CDS      USD
# 165                         20160504_PLCOAL_CDS        .
# 166                          20160622_NSINO_CDS      EUR
# 167                   20160622_NSINO_CDS-Bucket      EUR
# 168                 20160622_NSINO_CDS-Bucket-3      EUR
# 169                 20160622_NSINO_CDS-Bucket-4      EUR
# 170                  20160721_PLTMPL-IntFin_CDS      EUR
# 171                         20160817_CMNWPR_CDS      USD
# 172                        20160824_GRUPOIS_CDS      EUR
# 173                        20170202_IHEAINC_CDS      USD
# 174                       20170202_IHEAINC_LCDS      USD
# 175                            20170301_AV_LCDS  million
# 176                        20170711_GENOENE_CDS      USD
# 177                          20170802_PREPA_CDS      USD
# 178                          20170914_NSINO_CDS      EUR
# 179                   20170914_NSINO_CDS-Bucket      EUR
# 180                 20170914_NSINO_CDS-Bucket-3      EUR
# 181                 20170914_NSINO_CDS-Bucket-4      EUR
# 182                     20170921_MONTE_CDS-2014      EUR
# 183            20171005_BPESP_CDS-2003-Bucket-1      EUR
# 184            20171005_BPESP_CDS-2003-Bucket-2      EUR
# 185                          20171011_TOYS_LCDS      USD
# 186                     20171011_TOY_CDS-Senior      USD
# 187            20171101_MONTE_CDS-2003-Bucket-1      EUR
# 188            20171101_MONTE_CDS-2003-Bucket-2      EUR
# 189                           20171212_VENZ_CDS      USD
# 190                            20171213_PDV_CDS      USD
# 191                          20180425_NBLGP_CDS      USD
# 192                        20180425_NINEWES_CDS      USD
# 193                 20180502_NOVOBAN_CDS-Bucket      EUR
# 194              20180906_BPESP_CDS-Subordinate      EUR
# 195                 20181127_NOVOBAN_CDS-Senior     None
# 196                           20181129_ASTL_CDS      EUR
# 197                 20190117_SHC-Acceptance_CDS      USD
# 198                            20190123_PKD_CDS      USD
# 199                  20190227_PCGPacGasElec_CDS      USD
# 200                        20190403_WINDSSE_CDS      USD
# 201                       20190605_NEWLOOAC_CDS      EUR
# 202                           20190627_GENP_CDS      EUR
# 203                     20190724_WFT_CDS-Senior      USD
# 204                        20190807_GALAPHO_CDS      EUR
# 205                   20190911_TOGUN_CDS-Senior      EUR
# 206                        20190925_STEIEUR_CDS      EUR
# 207                    20191030_THCP_CDS-Senior      EUR
# 208                         20191210_DNSFDS_CDS      USD
# 209                         20200310_MCLTHY_CDS      USD
# 210                          20200423_LEBAN_CDS      USD
# 211                   20200506_WHPEC_CDS-Senior      USD
# 212                    20200513_FRCA_CDS-Senior      USD
# 213                           20200519_ECUA_CDS      USD
# 214                      20200522_DO_CDS-Senior      USD
# 215                         20200529_THENEI_CDS      USD
# 216                         20200604_INTINV_CDS      USD
# 217                     20200609_JCP_CDS-Senior      USD
# 218                         20200612_ARGENT_CDS      USD
# 219                        20200624_F-Hertz_CDS      USD
# 220                        20200707_CALIRES_CDS      USD
# 221                         20200729_WIREAG_CDS      EUR
# 222                            20200804_CHK_CDS      USD
# 223                        20200908_HEMABON_CDS      EUR
# 224                             20200910_NE_CDS      USD
# 225                        20200915_MATAFIN_CDS      GBP
# 226                        20201001_PIZZAFI_CDS      GBP
# 227                        20201020_SELEGRO_CDS        .
# 228                        20210113_EUROPMO_CDS        .
# 229                        20220607_TALEENE_CDS      USD
# 230                         20220912_RUSSIA_CDS      USD
# 231                         20220928_UKRAIN_CDS      USD
# 232                        20230413_DIAMSPO_CDS      USD

# %%
# Substitute $ with USD, € with EUR, and £ with GBP in the 'currency' column
data['currency'] = data['currency'].str.replace('$', 'USD').str.replace('€', 'EUR').str.replace('£', 'GBP')

# Remove all spaces from the 'currency' column
data['currency'] = data['currency'].str.replace(' ', '')

# Print the updated DataFrame
print(data[['identifier', 'currency']])
# Out:
#                                      identifier currency
# 0                           20051104_delphi_CDS      USD
# 1                          20060117_calpine_CDS      USD
# 2                 20060331_dana_corporation_CDS      USD
# 3                      20061128_dura_senior_CDS      USD
# 4                20061128_dura_subordinated_CDS      USD
# 5                   20071023_movie_gallery_LCDS      USD
# 6                           20080219_quebcr_CDS      USD
# 7                           20081002_tembec_CDS      USD
# 8           20081006_famefrmc_Fannie-Mae-Senior      USD
# 9     20081006_famefrmc_Fannie-Mae-Subordinated      USD
# 10         20081006_famefrmc_Freddie-Mac-Senior      USD
# 11   20081006_famefrmc_Freddie-Mac-Subordinated      USD
# 12                          20081010_lehbro_CDS      USD
# 13                          20081023_washmu_CDS      USD
# 14                       20081104_landsb_Senior      EUR
# 15                 20081104_landsb_Subordinated      EUR
# 16                       20081105_glitni_Senior      EUR
# 17                 20081105_glitni_Subordinated      EUR
# 18                       20081106_kaupth_Senior      EUR
# 19                 20081106_kaupth_Subordinated      EUR
# 20                          20081209_masoni_CDS      USD
# 21                          20081217_hawtel_CDS      USD
# 22                          20090106_tribco_CDS      USD
# 23                         20090106_tribco_LCDS      USD
# 24                          20090114_ecuado_CDS      USD
# 25                          20090203_equstr_CDS      USD
# 26                          20090203_lyodel_CDS      USD
# 27                         20090203_lyodel_LCDS      USD
# 28                          20090203_millen_CDS      USD
# 29                     20090205_sanitc_1st-Lien      EUR
# 30                     20090205_sanitc_2nd-Lien      EUR
# 31                         20090209_br_1st-Lien      GBP
# 32                         20090209_br_2nd-Lien      GBP
# 33                          20090210_norcor_CDS      USD
# 34                          20090210_norltd_CDS      USD
# 35                          20090219_smurfs_CDS      USD
# 36                         20090219_smurfs_LCDS      USD
# 37                         20090226_fereti_LCDS      EUR
# 38                         20090309_aleris_LCDS      USD
# 39                          20090331_stncas_CDS      USD
# 40                          20090414_chmtra_CDS      USD
# 41                          20090414_grtlak_CDS      USD
# 42                           20090415_rouse_CDS      USD
# 43                          20090416_lyobas_CDS      EUR
# 44                          20090417_abitbi_CDS      USD
# 45                          20090421_chacom_CDS      USD
# 46                         20090421_chacom_LCDS      USD
# 47                          20090422_capmrk_CDS      USD
# 48                          20090423_idearc_CDS      USD
# 49                         20090423_idearc_LCDS      USD
# 50                          20090512_bowatr_CDS      USD
# 51                         20090513_gegrpr_LCDS      USD
# 52                          20090527_syncra_CDS      USD
# 53                         20090528_edscha_LCDS      EUR
# 54                          20090609_hliop_LCDS      USD
# 55                         20090610_geguco_LCDS      USD
# 56                          20090610_jscbta_CDS      USD
# 57                          20090611_rhdcor_CDS      USD
# 58                          20090612_genmtr_CDS      USD
# 59                         20090612_genmtr_LCDS      USD
# 60                          20090618_jscali_CDS      USD
# 61                          20090623_viston_CDS      USD
# 62                         20090623_viston_LCDS      USD
# 63                         20090624_dexest_LCDS      USD
# 64                         20090624_dexwst_LCDS      USD
# 65                         20090624_rhdltd_LCDS      USD
# 66                          20090709_sixflg_CDS      USD
# 67                         20090709_sixflg_LCDS      USD
# 68                          20090721_leacor_CDS      USD
# 69                         20090721_leacor_LCDS      USD
# 70                       20090730_brabin_Senior      EUR
# 71                 20090730_brabin_Subordinated      EUR
# 72                         20091008_sspflt_LCDS      GBP
# 73     20091022_thmbrd_2.5-year-maturity-bucket      EUR
# 74       20091022_thmbrd_5-year-maturity-bucket      EUR
# 75     20091022_thmbrd_7.5-year-maturity-bucket      EUR
# 76                         20091110_mgminc_LCDS      USD
# 77                          20091120_citgrp_CDS      USD
# 78                          20091210_thomsn_CDS      EUR
# 79             20091215_hellas_CDS-Subordinated      EUR
# 80                          20091216_nafukr_CDS      USD
# 81                            20100107_fgic_CDS      USD
# 82                           20100218_cemex_CDS      USD
# 83                           20100325_aiful_CDS      JPY
# 84                   20100415_carstn_LCDS-LIEN1      GBP
# 85                          20100422_jalcor_CDS      JPY
# 86                   20100604_ABK-AssurCorp_CDS      USD
# 87                     20100715_TRUVO-SubCo_CDS      EUR
# 88                   20100909_WorldDir-B07_LCDS      EUR
# 89                           20100921_BOSG_LCDS      USD
# 90                          20101028_TAKFUJ_CDS      JPY
# 91       20101209_ANGBKL_CDS-SNR-or-SUB-Bucket1      EUR
# 92           20101209_ANGBKL_CDS-Senior-Bucket2      EUR
# 93           20101209_ANGBKL_CDS-Senior-Bucket3      EUR
# 94     20101209_ANGBKL_CDS-Subordinated-Bucket2      EUR
# 95     20101209_ANGBKL_CDS-Subordinated-Bucket3      EUR
# 96                             20101210_ABK_CDS      USD
# 97       20110202_ANGBKL2_CDS-25-years-maturity      EUR
# 98                      20110630_AIB_CDS-Senior      EUR
# 99                20110630_AIB_CDS-Subordinated      EUR
# 100        20110728_BKIR_CDS-SNR-or-SUB-Bucket1      EUR
# 101            20110728_BKIR_CDS-Senior-Bucket2      EUR
# 102            20110728_BKIR_CDS-Senior-Bucket3      EUR
# 103            20110728_BKIR_CDS-Senior-Bucket6      EUR
# 104      20110728_BKIR_CDS-Subordinated-Bucket2      EUR
# 105      20110728_BKIR_CDS-Subordinated-Bucket3      EUR
# 106      20110728_BKIR_CDS-Subordinated-Bucket6      EUR
# 107            20110729_IPBS_CDS-Senior-Bucket1      EUR
# 108            20110729_IPBS_CDS-Senior-Bucket2      EUR
# 109            20110729_IPBS_CDS-Senior-Bucket3      EUR
# 110      20110729_IPBS_CDS-Subordinated-Bucket1      EUR
# 111      20110729_IPBS_CDS-Subordinated-Bucket2      EUR
# 112      20110729_IPBS_CDS-Subordinated-Bucket3      EUR
# 113          20111005_IPBS2_CDS-Senior-Bucket-1      EUR
# 114          20111005_IPBS2_CDS-Senior-Bucket-2      EUR
# 115                            20111109_JVC_CDS      JPY
# 116                        20111123_PANRIC_LCDS      EUR
# 117                         20111129_DYNHLD_CDS      USD
# 118                          20111209_SPGIM_CDS      EUR
# 119                            20111213_PMI_CDS      USD
# 120                            20111215_AMR_CDS      USD
# 121                      20120117_Seat-A05_LCDS      EUR
# 122                 20120202_NRAMC_CDS-Bucket-1      EUR
# 123                 20120202_NRAMC_CDS-Bucket-2      EUR
# 124                             20120222_EK_CDS      USD
# 125                         20120319_GREECE_CDS      EUR
# 126                  20120322_HITACH-Elpida_CDS      JPY
# 127                         20120328_FCGIA_LCDS  million
# 128                         20120329_ERCIFT_CDS      EUR
# 129                  20120426_HAWKER-Acqui_LCDS      USD
# 130            20120502_ELCDS-Eircom_LCDS-LIEN1  million
# 131            20120502_ELCDS-Eircom_LCDS-LIEN2      EUR
# 132                           20120509_SIFO_CDS      USD
# 133                         20120530_HTNMIF_CDS      USD
# 134                     20120606_GM-ResCLLC_CDS      USD
# 135              20121115_ELCDS-Yell_LCDS-LIEN1      EUR
# 136                            20121206_OSG_CDS      USD
# 137                20130116_EIX-EdMisEnergy_CDS      USD
# 138                      20130131_PJHOLDCO_LCDS      EUR
# 139              20130404_SNSBNK_CDS-SNR-or-SUB      EUR
# 140     20130404_SNSBNK_CDS-SNR-or-SUB-Bucket-1      EUR
# 141                          20130424_DXMI_LCDS  million
# 142                          20130424_SPMD_LCDS  million
# 143              20130605_BANKSA_CDS-SNR-or-SUB      EUR
# 144     20130605_BANKSA_CDS-SNR-or-SUB-Bucket-1      EUR
# 145     20130605_BANKSA_CDS-SNR-or-SUB-Bucket-2      EUR
# 146     20130605_BANKSA_CDS-SNR-or-SUB-Bucket-3      EUR
# 147                         20130606_URBISA_CDS      USD
# 148                        20130806_CENGLQ_LCDS      USD
# 149                      20131009_CODSA-Fin_CDS      EUR
# 150                         20131204_OGXPET_CDS      USD
# 151                        20140521_ENERFUT_CDS  Million
# 152                        20140521_ENERGFU_CDS      USD
# 153          20140521_TXU-Texas-LCDS_LCDS-LIEN1      USD
# 154                      20140521_TXU-Texas_CDS      USD
# 155                       20140819_SOLOGRO_LCDS      EUR
# 156                         20140903_ARGENT_CDS      USD
# 157                         20150219_CESEOP_CDS      USD
# 158                        20150219_CESEOP_LCDS      USD
# 159                            20150305_RSH_CDS      USD
# 160                        20150623_SABINOI_CDS      USD
# 161                           20150917_AAHI_CDS      USD
# 162                         20151006_UKRAIN_CDS      USD
# 163                           20160114_ABNG_CDS      EUR
# 164                        20160406_PACIEXP_CDS      USD
# 165                         20160504_PLCOAL_CDS        .
# 166                          20160622_NSINO_CDS      EUR
# 167                   20160622_NSINO_CDS-Bucket      EUR
# 168                 20160622_NSINO_CDS-Bucket-3      EUR
# 169                 20160622_NSINO_CDS-Bucket-4      EUR
# 170                  20160721_PLTMPL-IntFin_CDS      EUR
# 171                         20160817_CMNWPR_CDS      USD
# 172                        20160824_GRUPOIS_CDS      EUR
# 173                        20170202_IHEAINC_CDS      USD
# 174                       20170202_IHEAINC_LCDS      USD
# 175                            20170301_AV_LCDS  million
# 176                        20170711_GENOENE_CDS      USD
# 177                          20170802_PREPA_CDS      USD
# 178                          20170914_NSINO_CDS      EUR
# 179                   20170914_NSINO_CDS-Bucket      EUR
# 180                 20170914_NSINO_CDS-Bucket-3      EUR
# 181                 20170914_NSINO_CDS-Bucket-4      EUR
# 182                     20170921_MONTE_CDS-2014      EUR
# 183            20171005_BPESP_CDS-2003-Bucket-1      EUR
# 184            20171005_BPESP_CDS-2003-Bucket-2      EUR
# 185                          20171011_TOYS_LCDS      USD
# 186                     20171011_TOY_CDS-Senior      USD
# 187            20171101_MONTE_CDS-2003-Bucket-1      EUR
# 188            20171101_MONTE_CDS-2003-Bucket-2      EUR
# 189                           20171212_VENZ_CDS      USD
# 190                            20171213_PDV_CDS      USD
# 191                          20180425_NBLGP_CDS      USD
# 192                        20180425_NINEWES_CDS      USD
# 193                 20180502_NOVOBAN_CDS-Bucket      EUR
# 194              20180906_BPESP_CDS-Subordinate      EUR
# 195                 20181127_NOVOBAN_CDS-Senior     None
# 196                           20181129_ASTL_CDS      EUR
# 197                 20190117_SHC-Acceptance_CDS      USD
# 198                            20190123_PKD_CDS      USD
# 199                  20190227_PCGPacGasElec_CDS      USD
# 200                        20190403_WINDSSE_CDS      USD
# 201                       20190605_NEWLOOAC_CDS      EUR
# 202                           20190627_GENP_CDS      EUR
# 203                     20190724_WFT_CDS-Senior      USD
# 204                        20190807_GALAPHO_CDS      EUR
# 205                   20190911_TOGUN_CDS-Senior      EUR
# 206                        20190925_STEIEUR_CDS      EUR
# 207                    20191030_THCP_CDS-Senior      EUR
# 208                         20191210_DNSFDS_CDS      USD
# 209                         20200310_MCLTHY_CDS      USD
# 210                          20200423_LEBAN_CDS      USD
# 211                   20200506_WHPEC_CDS-Senior      USD
# 212                    20200513_FRCA_CDS-Senior      USD
# 213                           20200519_ECUA_CDS      USD
# 214                      20200522_DO_CDS-Senior      USD
# 215                         20200529_THENEI_CDS      USD
# 216                         20200604_INTINV_CDS      USD
# 217                     20200609_JCP_CDS-Senior      USD
# 218                         20200612_ARGENT_CDS      USD
# 219                        20200624_F-Hertz_CDS      USD
# 220                        20200707_CALIRES_CDS      USD
# 221                         20200729_WIREAG_CDS      EUR
# 222                            20200804_CHK_CDS      USD
# 223                        20200908_HEMABON_CDS      EUR
# 224                             20200910_NE_CDS      USD
# 225                        20200915_MATAFIN_CDS      GBP
# 226                        20201001_PIZZAFI_CDS      GBP
# 227                        20201020_SELEGRO_CDS        .
# 228                        20210113_EUROPMO_CDS        .
# 229                        20220607_TALEENE_CDS      USD
# 230                         20220912_RUSSIA_CDS      USD
# 231                         20220928_UKRAIN_CDS      USD
# 232                        20230413_DIAMSPO_CDS      USD
# /tmp/ipykernel_39105/1969070466.py:2: FutureWarning: The default value of regex will change from True to False in a future version. In addition, single character regular expressions will *not* be treated as literal strings when regex=True.
#   data['currency'] = data['currency'].str.replace('$', 'USD').str.replace('€', 'EUR').str.replace('£', 'GBP')

# %%
missing_currency_count = data['currency'].isnull().sum()
print("Number of missing values in 'currency' column:", missing_currency_count)
# Out:
# Number of missing values in 'currency' column: 1

# %%
import os
import pandas as pd

database_path = '../../data/raw_auction_csv'

# Iterate over each row of the dataset
for index, row in data.iterrows():
    identifier = row['identifier']
    currency = row['currency']
    exchange_rate = None
    currencies_exchange = None

    # Check if currency is USD or $
    if currency is not None and ('USD' in currency or currency == '$'):
        exchange_rate = 1
        currencies_exchange = "USD/USD"
        print(f"Identifier: {identifier} - Currency is USD or $, exchange rate set to 1")
    else:
        # Look for CSV files in the folder
        csv_files = [file for file in os.listdir(database_path) if file.endswith('.csv') and all(word not in file for word in ['Final Price', 'Limit Orders', 'NOI', 'IMM', 'Physical', 'Markets'])]
        #print(f"Identifier: {identifier} - CSV files in folder: {csv_files}")

        # Check if the identifier matches any CSV file name
        matching_files = [file for file in csv_files if identifier in file]
        print(f"Identifier: {identifier} - Matching files: {matching_files}")

        if matching_files:
            for csv_file in matching_files:
                print(f"Identifier: {identifier} - Selected CSV file: {csv_file}")
                csv_path = os.path.join(database_path, csv_file)
                df_csv = pd.read_csv(csv_path, header=None)
                print(f"Identifier: {identifier} - CSV file contents:\n{df_csv}")
                if 'Auction Currency Rates' in str(df_csv.iloc[0, 0]):
                    usd_rates = df_csv[df_csv.iloc[:, 0].str.contains('USD')]
                    if not usd_rates.empty:
                        exchange_rate = usd_rates.iloc[-1, 1]
                        currencies_exchange = usd_rates.iloc[-1, 0]
                        print(f"Identifier: {identifier} - Found 'Auction Currency Rates' in row: {currencies_exchange}")
                        print(f"Identifier: {identifier} - Exchange rate found: {exchange_rate}")
                        break  # Break the loop if a match is found
                    else:
                        exchange_rate = df_csv.iloc[-1, 1]
                        currencies_exchange = df_csv.iloc[-1, 0]
                        print(f"Identifier: {identifier} - Found 'Auction Currency Rates' in the last row")
                        print(f"Identifier: {identifier} - Exchange rate found: {exchange_rate}")


    # Update the exchange_rate column in the data at the corresponding row of the identifier
    data.loc[index, 'exchange_rate'] = exchange_rate
    data.loc[index, 'currencies_exchange'] = currencies_exchange

# Fill empty 'currency' values with the first three letters of 'currencies_exchange'
data['currency'].fillna(data['currencies_exchange'].str[:3], inplace=True)

# Fill values that have 'million', 'Million', or '.' with the first three letters of 'currencies_exchange'
data.loc[data['currency'].isin(['million', 'Million', '.']), 'currency'] = data['currencies_exchange'].str[:3]


pd.set_option('display.max_columns', None)
pd.set_option('display.max_rows', None)

# Print the updated DataFrame
print(data[['identifier', 'NOI', 'noi_absolute_value','currency', 'exchange_rate', 'currencies_exchange']])
# Out:
# Identifier: 20051104_delphi_CDS - Currency is USD or $, exchange rate set to 1
# Identifier: 20060117_calpine_CDS - Currency is USD or $, exchange rate set to 1
# Identifier: 20060331_dana_corporation_CDS - Currency is USD or $, exchange rate set to 1
# Identifier: 20061128_dura_senior_CDS - Currency is USD or $, exchange rate set to 1
# Identifier: 20061128_dura_subordinated_CDS - Currency is USD or $, exchange rate set to 1
# Identifier: 20071023_movie_gallery_LCDS - Currency is USD or $, exchange rate set to 1
# Identifier: 20080219_quebcr_CDS - Currency is USD or $, exchange rate set to 1
# Identifier: 20081002_tembec_CDS - Currency is USD or $, exchange rate set to 1
# Identifier: 20081006_famefrmc_Fannie-Mae-Senior - Currency is USD or $, exchange rate set to 1
# Identifier: 20081006_famefrmc_Fannie-Mae-Subordinated - Currency is USD or $, exchange rate set to 1
# Identifier: 20081006_famefrmc_Freddie-Mac-Senior - Currency is USD or $, exchange rate set to 1
# Identifier: 20081006_famefrmc_Freddie-Mac-Subordinated - Currency is USD or $, exchange rate set to 1
# Identifier: 20081010_lehbro_CDS - Currency is USD or $, exchange rate set to 1
# Identifier: 20081023_washmu_CDS - Currency is USD or $, exchange rate set to 1
# Identifier: 20081104_landsb_Senior - Matching files: []
# Identifier: 20081104_landsb_Subordinated - Matching files: []
# Identifier: 20081105_glitni_Senior - Matching files: []
# Identifier: 20081105_glitni_Subordinated - Matching files: []
# Identifier: 20081106_kaupth_Senior - Matching files: []
# Identifier: 20081106_kaupth_Subordinated - Matching files: []
# Identifier: 20081209_masoni_CDS - Currency is USD or $, exchange rate set to 1
# Identifier: 20081217_hawtel_CDS - Currency is USD or $, exchange rate set to 1
# Identifier: 20090106_tribco_CDS - Currency is USD or $, exchange rate set to 1
# Identifier: 20090106_tribco_LCDS - Currency is USD or $, exchange rate set to 1
# Identifier: 20090114_ecuado_CDS - Currency is USD or $, exchange rate set to 1
# Identifier: 20090203_equstr_CDS - Currency is USD or $, exchange rate set to 1
# Identifier: 20090203_lyodel_CDS - Currency is USD or $, exchange rate set to 1
# Identifier: 20090203_lyodel_LCDS - Currency is USD or $, exchange rate set to 1
# Identifier: 20090203_millen_CDS - Currency is USD or $, exchange rate set to 1
# Identifier: 20090205_sanitc_1st-Lien - Matching files: []
# Identifier: 20090205_sanitc_2nd-Lien - Matching files: []
# Identifier: 20090209_br_1st-Lien - Matching files: []
# Identifier: 20090209_br_2nd-Lien - Matching files: []
# Identifier: 20090210_norcor_CDS - Currency is USD or $, exchange rate set to 1
# Identifier: 20090210_norltd_CDS - Currency is USD or $, exchange rate set to 1
# Identifier: 20090219_smurfs_CDS - Currency is USD or $, exchange rate set to 1
# Identifier: 20090219_smurfs_LCDS - Currency is USD or $, exchange rate set to 1
# Identifier: 20090226_fereti_LCDS - Matching files: []
# Identifier: 20090309_aleris_LCDS - Currency is USD or $, exchange rate set to 1
# Identifier: 20090331_stncas_CDS - Currency is USD or $, exchange rate set to 1
# Identifier: 20090414_chmtra_CDS - Currency is USD or $, exchange rate set to 1
# Identifier: 20090414_grtlak_CDS - Currency is USD or $, exchange rate set to 1
# Identifier: 20090415_rouse_CDS - Currency is USD or $, exchange rate set to 1
# Identifier: 20090416_lyobas_CDS - Matching files: []
# Identifier: 20090417_abitbi_CDS - Currency is USD or $, exchange rate set to 1
# Identifier: 20090421_chacom_CDS - Currency is USD or $, exchange rate set to 1
# Identifier: 20090421_chacom_LCDS - Currency is USD or $, exchange rate set to 1
# Identifier: 20090422_capmrk_CDS - Currency is USD or $, exchange rate set to 1
# Identifier: 20090423_idearc_CDS - Currency is USD or $, exchange rate set to 1
# Identifier: 20090423_idearc_LCDS - Currency is USD or $, exchange rate set to 1
# Identifier: 20090512_bowatr_CDS - Currency is USD or $, exchange rate set to 1
# Identifier: 20090513_gegrpr_LCDS - Currency is USD or $, exchange rate set to 1
# Identifier: 20090527_syncra_CDS - Currency is USD or $, exchange rate set to 1
# Identifier: 20090528_edscha_LCDS - Matching files: []
# Identifier: 20090609_hliop_LCDS - Currency is USD or $, exchange rate set to 1
# Identifier: 20090610_geguco_LCDS - Currency is USD or $, exchange rate set to 1
# Identifier: 20090610_jscbta_CDS - Currency is USD or $, exchange rate set to 1
# Identifier: 20090611_rhdcor_CDS - Currency is USD or $, exchange rate set to 1
# Identifier: 20090612_genmtr_CDS - Currency is USD or $, exchange rate set to 1
# Identifier: 20090612_genmtr_LCDS - Currency is USD or $, exchange rate set to 1
# Identifier: 20090618_jscali_CDS - Currency is USD or $, exchange rate set to 1
# Identifier: 20090623_viston_CDS - Currency is USD or $, exchange rate set to 1
# Identifier: 20090623_viston_LCDS - Currency is USD or $, exchange rate set to 1
# Identifier: 20090624_dexest_LCDS - Currency is USD or $, exchange rate set to 1
# Identifier: 20090624_dexwst_LCDS - Currency is USD or $, exchange rate set to 1
# Identifier: 20090624_rhdltd_LCDS - Currency is USD or $, exchange rate set to 1
# Identifier: 20090709_sixflg_CDS - Currency is USD or $, exchange rate set to 1
# Identifier: 20090709_sixflg_LCDS - Currency is USD or $, exchange rate set to 1
# Identifier: 20090721_leacor_CDS - Currency is USD or $, exchange rate set to 1
# Identifier: 20090721_leacor_LCDS - Currency is USD or $, exchange rate set to 1
# Identifier: 20090730_brabin_Senior - Matching files: ['20090730_brabin_Senior_Final Results of the Bradford & Bi_0.csv', '20090730_brabin_Senior_Final Results of the Bradford & Bi_1.csv']
# Identifier: 20090730_brabin_Senior - Selected CSV file: 20090730_brabin_Senior_Final Results of the Bradford & Bi_0.csv
# Identifier: 20090730_brabin_Senior - CSV file contents:
#                    0
# 0  Relevant Currency
# 1                EUR
# Identifier: 20090730_brabin_Senior - Selected CSV file: 20090730_brabin_Senior_Final Results of the Bradford & Bi_1.csv
# Identifier: 20090730_brabin_Senior - CSV file contents:
#                         0                         1
# 0  Auction Currency Rates  Auction Currency Rates.1
# 1                 EUR/CHF                   0.65585
# 2                 EUR/EUR                       1.0
# 3                 EUR/GBP                   1.15995
# Identifier: 20090730_brabin_Senior - Found 'Auction Currency Rates' in the last row
# Identifier: 20090730_brabin_Senior - Exchange rate found: 1.15995
# Identifier: 20090730_brabin_Subordinated - Matching files: ['20090730_brabin_Subordinated_Final Results of the Bradford & Bi_7.csv', '20090730_brabin_Subordinated_Final Results of the Bradford & Bi_6.csv']
# Identifier: 20090730_brabin_Subordinated - Selected CSV file: 20090730_brabin_Subordinated_Final Results of the Bradford & Bi_7.csv
# Identifier: 20090730_brabin_Subordinated - CSV file contents:
#                         0                         1
# 0  Auction Currency Rates  Auction Currency Rates.1
# 1                 EUR/CHF                   0.65585
# 2                 EUR/EUR                       1.0
# 3                 EUR/GBP                   1.15995
# Identifier: 20090730_brabin_Subordinated - Found 'Auction Currency Rates' in the last row
# Identifier: 20090730_brabin_Subordinated - Exchange rate found: 1.15995
# Identifier: 20090730_brabin_Subordinated - Selected CSV file: 20090730_brabin_Subordinated_Final Results of the Bradford & Bi_6.csv
# Identifier: 20090730_brabin_Subordinated - CSV file contents:
#                    0
# 0  Relevant Currency
# 1                EUR
# Identifier: 20091008_sspflt_LCDS - Matching files: []
# Identifier: 20091022_thmbrd_2.5-year-maturity-bucket - Matching files: ['20091022_thmbrd_2.5-year-maturity-bucket_Final Results of the Thomson\n 2.5-_1.csv', '20091022_thmbrd_2.5-year-maturity-bucket_Final Results of the Thomson\n 2.5-_0.csv']
# Identifier: 20091022_thmbrd_2.5-year-maturity-bucket - Selected CSV file: 20091022_thmbrd_2.5-year-maturity-bucket_Final Results of the Thomson
#  2.5-_1.csv
# Identifier: 20091022_thmbrd_2.5-year-maturity-bucket - CSV file contents:
#                         0                         1
# 0  Auction Currency Rates  Auction Currency Rates.1
# 1                 EUR/EUR                       1.0
# 2                 EUR/USD                   0.66921
# Identifier: 20091022_thmbrd_2.5-year-maturity-bucket - Found 'Auction Currency Rates' in row: EUR/USD
# Identifier: 20091022_thmbrd_2.5-year-maturity-bucket - Exchange rate found: 0.66921
# Identifier: 20091022_thmbrd_5-year-maturity-bucket - Matching files: ['20091022_thmbrd_5-year-maturity-bucket_Final Results of the Thomson\n 5-ye_6.csv', '20091022_thmbrd_5-year-maturity-bucket_Final Results of the Thomson\n 5-ye_7.csv']
# Identifier: 20091022_thmbrd_5-year-maturity-bucket - Selected CSV file: 20091022_thmbrd_5-year-maturity-bucket_Final Results of the Thomson
#  5-ye_6.csv
# Identifier: 20091022_thmbrd_5-year-maturity-bucket - CSV file contents:
#                    0
# 0  Relevant Currency
# 1                EUR
# Identifier: 20091022_thmbrd_5-year-maturity-bucket - Selected CSV file: 20091022_thmbrd_5-year-maturity-bucket_Final Results of the Thomson
#  5-ye_7.csv
# Identifier: 20091022_thmbrd_5-year-maturity-bucket - CSV file contents:
#                         0                         1
# 0  Auction Currency Rates  Auction Currency Rates.1
# 1                 EUR/EUR                       1.0
# 2                 EUR/USD                   0.66921
# Identifier: 20091022_thmbrd_5-year-maturity-bucket - Found 'Auction Currency Rates' in row: EUR/USD
# Identifier: 20091022_thmbrd_5-year-maturity-bucket - Exchange rate found: 0.66921
# Identifier: 20091022_thmbrd_7.5-year-maturity-bucket - Matching files: ['20091022_thmbrd_7.5-year-maturity-bucket_Final Results of the Thomson\n 7.5-_13.csv', '20091022_thmbrd_7.5-year-maturity-bucket_Final Results of the Thomson\n 7.5-_12.csv']
# Identifier: 20091022_thmbrd_7.5-year-maturity-bucket - Selected CSV file: 20091022_thmbrd_7.5-year-maturity-bucket_Final Results of the Thomson
#  7.5-_13.csv
# Identifier: 20091022_thmbrd_7.5-year-maturity-bucket - CSV file contents:
#                         0                         1
# 0  Auction Currency Rates  Auction Currency Rates.1
# 1                 EUR/EUR                       1.0
# 2                 EUR/USD                   0.66921
# Identifier: 20091022_thmbrd_7.5-year-maturity-bucket - Found 'Auction Currency Rates' in row: EUR/USD
# Identifier: 20091022_thmbrd_7.5-year-maturity-bucket - Exchange rate found: 0.66921
# Identifier: 20091110_mgminc_LCDS - Currency is USD or $, exchange rate set to 1
# Identifier: 20091120_citgrp_CDS - Currency is USD or $, exchange rate set to 1
# Identifier: 20091210_thomsn_CDS - Matching files: ['20091210_thomsn_CDS_Final Results of the Thomson  (Ban_0.csv', '20091210_thomsn_CDS_Final Results of the Thomson  (Ban_1.csv']
# Identifier: 20091210_thomsn_CDS - Selected CSV file: 20091210_thomsn_CDS_Final Results of the Thomson  (Ban_0.csv
# Identifier: 20091210_thomsn_CDS - CSV file contents:
#                    0
# 0  Relevant Currency
# 1                EUR
# Identifier: 20091210_thomsn_CDS - Selected CSV file: 20091210_thomsn_CDS_Final Results of the Thomson  (Ban_1.csv
# Identifier: 20091210_thomsn_CDS - CSV file contents:
#                         0                         1
# 0  Auction Currency Rates  Auction Currency Rates.1
# 1                 EUR/EUR                       1.0
# 2                 EUR/USD                   0.67866
# Identifier: 20091210_thomsn_CDS - Found 'Auction Currency Rates' in row: EUR/USD
# Identifier: 20091210_thomsn_CDS - Exchange rate found: 0.67866
# Identifier: 20091215_hellas_CDS-Subordinated - Matching files: ['20091215_hellas_CDS-Subordinated_Final Results of the Hellas II CDS_1.csv', '20091215_hellas_CDS-Subordinated_Final Results of the Hellas II CDS_0.csv']
# Identifier: 20091215_hellas_CDS-Subordinated - Selected CSV file: 20091215_hellas_CDS-Subordinated_Final Results of the Hellas II CDS_1.csv
# Identifier: 20091215_hellas_CDS-Subordinated - CSV file contents:
#                         0                         1
# 0  Auction Currency Rates  Auction Currency Rates.1
# 1                 EUR/EUR                       1.0
# 2                 EUR/USD                    0.6839
# Identifier: 20091215_hellas_CDS-Subordinated - Found 'Auction Currency Rates' in row: EUR/USD
# Identifier: 20091215_hellas_CDS-Subordinated - Exchange rate found: 0.6839
# Identifier: 20091216_nafukr_CDS - Currency is USD or $, exchange rate set to 1
# Identifier: 20100107_fgic_CDS - Currency is USD or $, exchange rate set to 1
# Identifier: 20100218_cemex_CDS - Currency is USD or $, exchange rate set to 1
# Identifier: 20100325_aiful_CDS - Matching files: ['20100325_aiful_CDS_Final Results of the Aiful CDS\n   1.csv', '20100325_aiful_CDS_Final Results of the Aiful CDS\n   0.csv']
# Identifier: 20100325_aiful_CDS - Selected CSV file: 20100325_aiful_CDS_Final Results of the Aiful CDS
#    1.csv
# Identifier: 20100325_aiful_CDS - CSV file contents:
#                         0                         1
# 0  Auction Currency Rates  Auction Currency Rates.1
# 1                 JPY/USD                     90.34
# 2                 JPY/JPY                       1.0
# Identifier: 20100325_aiful_CDS - Found 'Auction Currency Rates' in row: JPY/USD
# Identifier: 20100325_aiful_CDS - Exchange rate found: 90.34
# Identifier: 20100415_carstn_LCDS-LIEN1 - Matching files: []
# Identifier: 20100422_jalcor_CDS - Matching files: ['20100422_jalcor_CDS_Final Results of the Japan Airline1.csv', '20100422_jalcor_CDS_Final Results of the Japan Airline0.csv']
# Identifier: 20100422_jalcor_CDS - Selected CSV file: 20100422_jalcor_CDS_Final Results of the Japan Airline1.csv
# Identifier: 20100422_jalcor_CDS - CSV file contents:
#                         0                         1
# 0  Auction Currency Rates  Auction Currency Rates.1
# 1                 JPY/JPY                       1.0
# Identifier: 20100422_jalcor_CDS - Found 'Auction Currency Rates' in the last row
# Identifier: 20100422_jalcor_CDS - Exchange rate found: 1.0
# Identifier: 20100422_jalcor_CDS - Selected CSV file: 20100422_jalcor_CDS_Final Results of the Japan Airline0.csv
# Identifier: 20100422_jalcor_CDS - CSV file contents:
#                    0
# 0  Relevant Currency
# 1                JPY
# Identifier: 20100604_ABK-AssurCorp_CDS - Currency is USD or $, exchange rate set to 1
# Identifier: 20100715_TRUVO-SubCo_CDS - Matching files: ['20100715_TRUVO-SubCo_CDS_Final Results of the Truvo Subsidi_1.csv', '20100715_TRUVO-SubCo_CDS_Final Results of the Truvo Subsidi_0.csv']
# Identifier: 20100715_TRUVO-SubCo_CDS - Selected CSV file: 20100715_TRUVO-SubCo_CDS_Final Results of the Truvo Subsidi_1.csv
# Identifier: 20100715_TRUVO-SubCo_CDS - CSV file contents:
#                         0                         1
# 0  Auction Currency Rates  Auction Currency Rates.1
# 1                 EUR/EUR                       1.0
# 2                 EUR/USD                    0.7893
# Identifier: 20100715_TRUVO-SubCo_CDS - Found 'Auction Currency Rates' in row: EUR/USD
# Identifier: 20100715_TRUVO-SubCo_CDS - Exchange rate found: 0.7893
# Identifier: 20100909_WorldDir-B07_LCDS - Matching files: []
# Identifier: 20100921_BOSG_LCDS - Currency is USD or $, exchange rate set to 1
# Identifier: 20101028_TAKFUJ_CDS - Matching files: ['20101028_TAKFUJ_CDS_Final Results of the Takefuji Corp_1.csv', '20101028_TAKFUJ_CDS_Final Results of the Takefuji Corp_0.csv']
# Identifier: 20101028_TAKFUJ_CDS - Selected CSV file: 20101028_TAKFUJ_CDS_Final Results of the Takefuji Corp_1.csv
# Identifier: 20101028_TAKFUJ_CDS - CSV file contents:
#                         0                         1
# 0  Auction Currency Rates  Auction Currency Rates.1
# 1                 JPY/USD                     80.72
# Identifier: 20101028_TAKFUJ_CDS - Found 'Auction Currency Rates' in row: JPY/USD
# Identifier: 20101028_TAKFUJ_CDS - Exchange rate found: 80.72
# Identifier: 20101209_ANGBKL_CDS-SNR-or-SUB-Bucket1 - Matching files: ['20101209_ANGBKL_CDS-SNR-or-SUB-Bucket1_Final Results of the Anglo Irish B_13.csv', '20101209_ANGBKL_CDS-SNR-or-SUB-Bucket1_Final Results of the Anglo Irish B_12.csv']
# Identifier: 20101209_ANGBKL_CDS-SNR-or-SUB-Bucket1 - Selected CSV file: 20101209_ANGBKL_CDS-SNR-or-SUB-Bucket1_Final Results of the Anglo Irish B_13.csv
# Identifier: 20101209_ANGBKL_CDS-SNR-or-SUB-Bucket1 - CSV file contents:
#                         0                         1
# 0  Auction Currency Rates  Auction Currency Rates.1
# 1                 EUR/EUR                       1.0
# 2                 EUR/GBP                   1.18526
# 3                 EUR/JPY                   0.00902
# 4                 EUR/USD                   0.74937
# Identifier: 20101209_ANGBKL_CDS-SNR-or-SUB-Bucket1 - Found 'Auction Currency Rates' in row: EUR/USD
# Identifier: 20101209_ANGBKL_CDS-SNR-or-SUB-Bucket1 - Exchange rate found: 0.74937
# Identifier: 20101209_ANGBKL_CDS-Senior-Bucket2 - Matching files: ['20101209_ANGBKL_CDS-Senior-Bucket2_Final Results of the Anglo Irish B_25.csv', '20101209_ANGBKL_CDS-Senior-Bucket2_Final Results of the Anglo Irish B_24.csv']
# Identifier: 20101209_ANGBKL_CDS-Senior-Bucket2 - Selected CSV file: 20101209_ANGBKL_CDS-Senior-Bucket2_Final Results of the Anglo Irish B_25.csv
# Identifier: 20101209_ANGBKL_CDS-Senior-Bucket2 - CSV file contents:
#                         0                         1
# 0  Auction Currency Rates  Auction Currency Rates.1
# 1                 EUR/EUR                       1.0
# 2                 EUR/GBP                   1.18526
# 3                 EUR/JPY                   0.00902
# 4                 EUR/USD                   0.74937
# Identifier: 20101209_ANGBKL_CDS-Senior-Bucket2 - Found 'Auction Currency Rates' in row: EUR/USD
# Identifier: 20101209_ANGBKL_CDS-Senior-Bucket2 - Exchange rate found: 0.74937
# Identifier: 20101209_ANGBKL_CDS-Senior-Bucket3 - Matching files: ['20101209_ANGBKL_CDS-Senior-Bucket3_Final Results of the Anglo Irish B_18.csv', '20101209_ANGBKL_CDS-Senior-Bucket3_Final Results of the Anglo Irish B_19.csv']
# Identifier: 20101209_ANGBKL_CDS-Senior-Bucket3 - Selected CSV file: 20101209_ANGBKL_CDS-Senior-Bucket3_Final Results of the Anglo Irish B_18.csv
# Identifier: 20101209_ANGBKL_CDS-Senior-Bucket3 - CSV file contents:
#                    0
# 0  Relevant Currency
# 1                EUR
# Identifier: 20101209_ANGBKL_CDS-Senior-Bucket3 - Selected CSV file: 20101209_ANGBKL_CDS-Senior-Bucket3_Final Results of the Anglo Irish B_19.csv
# Identifier: 20101209_ANGBKL_CDS-Senior-Bucket3 - CSV file contents:
#                         0                         1
# 0  Auction Currency Rates  Auction Currency Rates.1
# 1                 EUR/EUR                       1.0
# 2                 EUR/GBP                   1.18526
# 3                 EUR/JPY                   0.00902
# 4                 EUR/USD                   0.74937
# Identifier: 20101209_ANGBKL_CDS-Senior-Bucket3 - Found 'Auction Currency Rates' in row: EUR/USD
# Identifier: 20101209_ANGBKL_CDS-Senior-Bucket3 - Exchange rate found: 0.74937
# Identifier: 20101209_ANGBKL_CDS-Subordinated-Bucket2 - Matching files: ['20101209_ANGBKL_CDS-Subordinated-Bucket2_Final Results of the Anglo Irish B_1.csv', '20101209_ANGBKL_CDS-Subordinated-Bucket2_Final Results of the Anglo Irish B_0.csv']
# Identifier: 20101209_ANGBKL_CDS-Subordinated-Bucket2 - Selected CSV file: 20101209_ANGBKL_CDS-Subordinated-Bucket2_Final Results of the Anglo Irish B_1.csv
# Identifier: 20101209_ANGBKL_CDS-Subordinated-Bucket2 - CSV file contents:
#                         0                         1
# 0  Auction Currency Rates  Auction Currency Rates.1
# 1                 EUR/EUR                       1.0
# 2                 EUR/GBP                   1.18526
# 3                 EUR/JPY                   0.00902
# 4                 EUR/USD                   0.74937
# Identifier: 20101209_ANGBKL_CDS-Subordinated-Bucket2 - Found 'Auction Currency Rates' in row: EUR/USD
# Identifier: 20101209_ANGBKL_CDS-Subordinated-Bucket2 - Exchange rate found: 0.74937
# Identifier: 20101209_ANGBKL_CDS-Subordinated-Bucket3 - Matching files: ['20101209_ANGBKL_CDS-Subordinated-Bucket3_Final Results of the Anglo Irish B_7.csv', '20101209_ANGBKL_CDS-Subordinated-Bucket3_Final Results of the Anglo Irish B_6.csv']
# Identifier: 20101209_ANGBKL_CDS-Subordinated-Bucket3 - Selected CSV file: 20101209_ANGBKL_CDS-Subordinated-Bucket3_Final Results of the Anglo Irish B_7.csv
# Identifier: 20101209_ANGBKL_CDS-Subordinated-Bucket3 - CSV file contents:
#                         0                         1
# 0  Auction Currency Rates  Auction Currency Rates.1
# 1                 EUR/EUR                       1.0
# 2                 EUR/GBP                   1.18526
# 3                 EUR/JPY                   0.00902
# 4                 EUR/USD                   0.74937
# Identifier: 20101209_ANGBKL_CDS-Subordinated-Bucket3 - Found 'Auction Currency Rates' in row: EUR/USD
# Identifier: 20101209_ANGBKL_CDS-Subordinated-Bucket3 - Exchange rate found: 0.74937
# Identifier: 20101210_ABK_CDS - Currency is USD or $, exchange rate set to 1
# Identifier: 20110202_ANGBKL2_CDS-25-years-maturity - Matching files: ['20110202_ANGBKL2_CDS-25-years-maturity_Final Results of the Anglo Irish B_1.csv', '20110202_ANGBKL2_CDS-25-years-maturity_Final Results of the Anglo Irish B_0.csv']
# Identifier: 20110202_ANGBKL2_CDS-25-years-maturity - Selected CSV file: 20110202_ANGBKL2_CDS-25-years-maturity_Final Results of the Anglo Irish B_1.csv
# Identifier: 20110202_ANGBKL2_CDS-25-years-maturity - CSV file contents:
#                         0                         1
# 0  Auction Currency Rates  Auction Currency Rates.1
# 1                 EUR/EUR                       1.0
# 2                 EUR/GBP                   1.16835
# 3                 EUR/JPY                    0.0089
# 4                 EUR/USD                   0.72939
# Identifier: 20110202_ANGBKL2_CDS-25-years-maturity - Found 'Auction Currency Rates' in row: EUR/USD
# Identifier: 20110202_ANGBKL2_CDS-25-years-maturity - Exchange rate found: 0.72939
# Identifier: 20110630_AIB_CDS-Senior - Matching files: ['20110630_AIB_CDS-Senior_Final Results of the Allied Irish _1.csv', '20110630_AIB_CDS-Senior_Final Results of the Allied Irish _0.csv']
# Identifier: 20110630_AIB_CDS-Senior - Selected CSV file: 20110630_AIB_CDS-Senior_Final Results of the Allied Irish _1.csv
# Identifier: 20110630_AIB_CDS-Senior - CSV file contents:
#                         0                         1
# 0  Auction Currency Rates  Auction Currency Rates.1
# 1                 EUR/CHF                    0.8385
# 2                 EUR/EUR                       1.0
# 3                 EUR/GBP                    1.1149
# 4                 EUR/USD                   0.69662
# Identifier: 20110630_AIB_CDS-Senior - Found 'Auction Currency Rates' in row: EUR/USD
# Identifier: 20110630_AIB_CDS-Senior - Exchange rate found: 0.69662
# Identifier: 20110630_AIB_CDS-Subordinated - Matching files: ['20110630_AIB_CDS-Subordinated_Final Results of the Allied Irish _6.csv', '20110630_AIB_CDS-Subordinated_Final Results of the Allied Irish _7.csv']
# Identifier: 20110630_AIB_CDS-Subordinated - Selected CSV file: 20110630_AIB_CDS-Subordinated_Final Results of the Allied Irish _6.csv
# Identifier: 20110630_AIB_CDS-Subordinated - CSV file contents:
#                    0
# 0  Relevant Currency
# 1                EUR
# Identifier: 20110630_AIB_CDS-Subordinated - Selected CSV file: 20110630_AIB_CDS-Subordinated_Final Results of the Allied Irish _7.csv
# Identifier: 20110630_AIB_CDS-Subordinated - CSV file contents:
#                         0                         1
# 0  Auction Currency Rates  Auction Currency Rates.1
# 1                 EUR/CHF                    0.8385
# 2                 EUR/EUR                       1.0
# 3                 EUR/GBP                    1.1149
# 4                 EUR/USD                   0.69662
# Identifier: 20110630_AIB_CDS-Subordinated - Found 'Auction Currency Rates' in row: EUR/USD
# Identifier: 20110630_AIB_CDS-Subordinated - Exchange rate found: 0.69662
# Identifier: 20110728_BKIR_CDS-SNR-or-SUB-Bucket1 - Matching files: ['20110728_BKIR_CDS-SNR-or-SUB-Bucket1_Final Results of the The Governor _0.csv', '20110728_BKIR_CDS-SNR-or-SUB-Bucket1_Final Results of the The Governor _1.csv']
# Identifier: 20110728_BKIR_CDS-SNR-or-SUB-Bucket1 - Selected CSV file: 20110728_BKIR_CDS-SNR-or-SUB-Bucket1_Final Results of the The Governor _0.csv
# Identifier: 20110728_BKIR_CDS-SNR-or-SUB-Bucket1 - CSV file contents:
#                    0
# 0  Relevant Currency
# 1                EUR
# Identifier: 20110728_BKIR_CDS-SNR-or-SUB-Bucket1 - Selected CSV file: 20110728_BKIR_CDS-SNR-or-SUB-Bucket1_Final Results of the The Governor _1.csv
# Identifier: 20110728_BKIR_CDS-SNR-or-SUB-Bucket1 - CSV file contents:
#                         0                         1
# 0  Auction Currency Rates  Auction Currency Rates.1
# 1                 EUR/CAD                   0.73164
# 2                 EUR/CHF                   0.85988
# 3                 EUR/EUR                       1.0
# 4                 EUR/GBP                   1.13135
# 5                 EUR/JPY                   0.00884
# 6                 EUR/USD                   0.69035
# Identifier: 20110728_BKIR_CDS-SNR-or-SUB-Bucket1 - Found 'Auction Currency Rates' in row: EUR/USD
# Identifier: 20110728_BKIR_CDS-SNR-or-SUB-Bucket1 - Exchange rate found: 0.69035
# Identifier: 20110728_BKIR_CDS-Senior-Bucket2 - Matching files: ['20110728_BKIR_CDS-Senior-Bucket2_Final Results of the The Governor _7.csv', '20110728_BKIR_CDS-Senior-Bucket2_Final Results of the The Governor _6.csv']
# Identifier: 20110728_BKIR_CDS-Senior-Bucket2 - Selected CSV file: 20110728_BKIR_CDS-Senior-Bucket2_Final Results of the The Governor _7.csv
# Identifier: 20110728_BKIR_CDS-Senior-Bucket2 - CSV file contents:
#                         0                         1
# 0  Auction Currency Rates  Auction Currency Rates.1
# 1                 EUR/CAD                   0.73164
# 2                 EUR/CHF                   0.85988
# 3                 EUR/EUR                       1.0
# 4                 EUR/GBP                   1.13135
# 5                 EUR/JPY                   0.00884
# 6                 EUR/USD                   0.69035
# Identifier: 20110728_BKIR_CDS-Senior-Bucket2 - Found 'Auction Currency Rates' in row: EUR/USD
# Identifier: 20110728_BKIR_CDS-Senior-Bucket2 - Exchange rate found: 0.69035
# Identifier: 20110728_BKIR_CDS-Senior-Bucket3 - Matching files: ['20110728_BKIR_CDS-Senior-Bucket3_Final Results of the The Governor _12.csv', '20110728_BKIR_CDS-Senior-Bucket3_Final Results of the The Governor _13.csv']
# Identifier: 20110728_BKIR_CDS-Senior-Bucket3 - Selected CSV file: 20110728_BKIR_CDS-Senior-Bucket3_Final Results of the The Governor _12.csv
# Identifier: 20110728_BKIR_CDS-Senior-Bucket3 - CSV file contents:
#                    0
# 0  Relevant Currency
# 1                EUR
# Identifier: 20110728_BKIR_CDS-Senior-Bucket3 - Selected CSV file: 20110728_BKIR_CDS-Senior-Bucket3_Final Results of the The Governor _13.csv
# Identifier: 20110728_BKIR_CDS-Senior-Bucket3 - CSV file contents:
#                         0                         1
# 0  Auction Currency Rates  Auction Currency Rates.1
# 1                 EUR/CAD                   0.73164
# 2                 EUR/CHF                   0.85988
# 3                 EUR/EUR                       1.0
# 4                 EUR/GBP                   1.13135
# 5                 EUR/JPY                   0.00884
# 6                 EUR/USD                   0.69035
# Identifier: 20110728_BKIR_CDS-Senior-Bucket3 - Found 'Auction Currency Rates' in row: EUR/USD
# Identifier: 20110728_BKIR_CDS-Senior-Bucket3 - Exchange rate found: 0.69035
# Identifier: 20110728_BKIR_CDS-Senior-Bucket6 - Matching files: ['20110728_BKIR_CDS-Senior-Bucket6_Final Results of the The Governor _18.csv', '20110728_BKIR_CDS-Senior-Bucket6_Final Results of the The Governor _19.csv']
# Identifier: 20110728_BKIR_CDS-Senior-Bucket6 - Selected CSV file: 20110728_BKIR_CDS-Senior-Bucket6_Final Results of the The Governor _18.csv
# Identifier: 20110728_BKIR_CDS-Senior-Bucket6 - CSV file contents:
#                    0
# 0  Relevant Currency
# 1                EUR
# Identifier: 20110728_BKIR_CDS-Senior-Bucket6 - Selected CSV file: 20110728_BKIR_CDS-Senior-Bucket6_Final Results of the The Governor _19.csv
# Identifier: 20110728_BKIR_CDS-Senior-Bucket6 - CSV file contents:
#                         0                         1
# 0  Auction Currency Rates  Auction Currency Rates.1
# 1                 EUR/CAD                   0.73164
# 2                 EUR/CHF                   0.85988
# 3                 EUR/EUR                       1.0
# 4                 EUR/GBP                   1.13135
# 5                 EUR/JPY                   0.00884
# 6                 EUR/USD                   0.69035
# Identifier: 20110728_BKIR_CDS-Senior-Bucket6 - Found 'Auction Currency Rates' in row: EUR/USD
# Identifier: 20110728_BKIR_CDS-Senior-Bucket6 - Exchange rate found: 0.69035
# Identifier: 20110728_BKIR_CDS-Subordinated-Bucket2 - Matching files: ['20110728_BKIR_CDS-Subordinated-Bucket2_Final Results of the The Governor _24.csv', '20110728_BKIR_CDS-Subordinated-Bucket2_Final Results of the The Governor _25.csv']
# Identifier: 20110728_BKIR_CDS-Subordinated-Bucket2 - Selected CSV file: 20110728_BKIR_CDS-Subordinated-Bucket2_Final Results of the The Governor _24.csv
# Identifier: 20110728_BKIR_CDS-Subordinated-Bucket2 - CSV file contents:
#                    0
# 0  Relevant Currency
# 1                EUR
# Identifier: 20110728_BKIR_CDS-Subordinated-Bucket2 - Selected CSV file: 20110728_BKIR_CDS-Subordinated-Bucket2_Final Results of the The Governor _25.csv
# Identifier: 20110728_BKIR_CDS-Subordinated-Bucket2 - CSV file contents:
#                         0                         1
# 0  Auction Currency Rates  Auction Currency Rates.1
# 1                 EUR/CAD                   0.73164
# 2                 EUR/CHF                   0.85988
# 3                 EUR/EUR                       1.0
# 4                 EUR/GBP                   1.13135
# 5                 EUR/JPY                   0.00884
# 6                 EUR/USD                   0.69035
# Identifier: 20110728_BKIR_CDS-Subordinated-Bucket2 - Found 'Auction Currency Rates' in row: EUR/USD
# Identifier: 20110728_BKIR_CDS-Subordinated-Bucket2 - Exchange rate found: 0.69035
# Identifier: 20110728_BKIR_CDS-Subordinated-Bucket3 - Matching files: ['20110728_BKIR_CDS-Subordinated-Bucket3_Final Results of the The Governor _31.csv', '20110728_BKIR_CDS-Subordinated-Bucket3_Final Results of the The Governor _30.csv']
# Identifier: 20110728_BKIR_CDS-Subordinated-Bucket3 - Selected CSV file: 20110728_BKIR_CDS-Subordinated-Bucket3_Final Results of the The Governor _31.csv
# Identifier: 20110728_BKIR_CDS-Subordinated-Bucket3 - CSV file contents:
#                         0                         1
# 0  Auction Currency Rates  Auction Currency Rates.1
# 1                 EUR/CAD                   0.73164
# 2                 EUR/CHF                   0.85988
# 3                 EUR/EUR                       1.0
# 4                 EUR/GBP                   1.13135
# 5                 EUR/JPY                   0.00884
# 6                 EUR/USD                   0.69035
# Identifier: 20110728_BKIR_CDS-Subordinated-Bucket3 - Found 'Auction Currency Rates' in row: EUR/USD
# Identifier: 20110728_BKIR_CDS-Subordinated-Bucket3 - Exchange rate found: 0.69035
# Identifier: 20110728_BKIR_CDS-Subordinated-Bucket6 - Matching files: ['20110728_BKIR_CDS-Subordinated-Bucket6_Final Results of the The Governor _36.csv', '20110728_BKIR_CDS-Subordinated-Bucket6_Final Results of the The Governor _37.csv']
# Identifier: 20110728_BKIR_CDS-Subordinated-Bucket6 - Selected CSV file: 20110728_BKIR_CDS-Subordinated-Bucket6_Final Results of the The Governor _36.csv
# Identifier: 20110728_BKIR_CDS-Subordinated-Bucket6 - CSV file contents:
#                    0
# 0  Relevant Currency
# 1                EUR
# Identifier: 20110728_BKIR_CDS-Subordinated-Bucket6 - Selected CSV file: 20110728_BKIR_CDS-Subordinated-Bucket6_Final Results of the The Governor _37.csv
# Identifier: 20110728_BKIR_CDS-Subordinated-Bucket6 - CSV file contents:
#                         0                         1
# 0  Auction Currency Rates  Auction Currency Rates.1
# 1                 EUR/CAD                   0.73164
# 2                 EUR/CHF                   0.85988
# 3                 EUR/EUR                       1.0
# 4                 EUR/GBP                   1.13135
# 5                 EUR/JPY                   0.00884
# 6                 EUR/USD                   0.69035
# Identifier: 20110728_BKIR_CDS-Subordinated-Bucket6 - Found 'Auction Currency Rates' in row: EUR/USD
# Identifier: 20110728_BKIR_CDS-Subordinated-Bucket6 - Exchange rate found: 0.69035
# Identifier: 20110729_IPBS_CDS-Senior-Bucket1 - Matching files: ['20110729_IPBS_CDS-Senior-Bucket1_Final Results of the Irish Life an_0.csv', '20110729_IPBS_CDS-Senior-Bucket1_Final Results of the Irish Life an_1.csv']
# Identifier: 20110729_IPBS_CDS-Senior-Bucket1 - Selected CSV file: 20110729_IPBS_CDS-Senior-Bucket1_Final Results of the Irish Life an_0.csv
# Identifier: 20110729_IPBS_CDS-Senior-Bucket1 - CSV file contents:
#                    0
# 0  Relevant Currency
# 1                EUR
# Identifier: 20110729_IPBS_CDS-Senior-Bucket1 - Selected CSV file: 20110729_IPBS_CDS-Senior-Bucket1_Final Results of the Irish Life an_1.csv
# Identifier: 20110729_IPBS_CDS-Senior-Bucket1 - CSV file contents:
#                         0                         1
# 0  Auction Currency Rates  Auction Currency Rates.1
# 1                 EUR/EUR                       1.0
# 2                 EUR/GBP                   1.13598
# 3                 EUR/USD                   0.69524
# Identifier: 20110729_IPBS_CDS-Senior-Bucket1 - Found 'Auction Currency Rates' in row: EUR/USD
# Identifier: 20110729_IPBS_CDS-Senior-Bucket1 - Exchange rate found: 0.69524
# Identifier: 20110729_IPBS_CDS-Senior-Bucket2 - Matching files: ['20110729_IPBS_CDS-Senior-Bucket2_Final Results of the Irish Life an_6.csv', '20110729_IPBS_CDS-Senior-Bucket2_Final Results of the Irish Life an_7.csv']
# Identifier: 20110729_IPBS_CDS-Senior-Bucket2 - Selected CSV file: 20110729_IPBS_CDS-Senior-Bucket2_Final Results of the Irish Life an_6.csv
# Identifier: 20110729_IPBS_CDS-Senior-Bucket2 - CSV file contents:
#                    0
# 0  Relevant Currency
# 1                EUR
# Identifier: 20110729_IPBS_CDS-Senior-Bucket2 - Selected CSV file: 20110729_IPBS_CDS-Senior-Bucket2_Final Results of the Irish Life an_7.csv
# Identifier: 20110729_IPBS_CDS-Senior-Bucket2 - CSV file contents:
#                         0                         1
# 0  Auction Currency Rates  Auction Currency Rates.1
# 1                 EUR/EUR                       1.0
# 2                 EUR/GBP                   1.13598
# 3                 EUR/USD                   0.69524
# Identifier: 20110729_IPBS_CDS-Senior-Bucket2 - Found 'Auction Currency Rates' in row: EUR/USD
# Identifier: 20110729_IPBS_CDS-Senior-Bucket2 - Exchange rate found: 0.69524
# Identifier: 20110729_IPBS_CDS-Senior-Bucket3 - Matching files: ['20110729_IPBS_CDS-Senior-Bucket3_Final Results of the Irish Life an_12.csv', '20110729_IPBS_CDS-Senior-Bucket3_Final Results of the Irish Life an_13.csv']
# Identifier: 20110729_IPBS_CDS-Senior-Bucket3 - Selected CSV file: 20110729_IPBS_CDS-Senior-Bucket3_Final Results of the Irish Life an_12.csv
# Identifier: 20110729_IPBS_CDS-Senior-Bucket3 - CSV file contents:
#                    0
# 0  Relevant Currency
# 1                EUR
# Identifier: 20110729_IPBS_CDS-Senior-Bucket3 - Selected CSV file: 20110729_IPBS_CDS-Senior-Bucket3_Final Results of the Irish Life an_13.csv
# Identifier: 20110729_IPBS_CDS-Senior-Bucket3 - CSV file contents:
#                         0                         1
# 0  Auction Currency Rates  Auction Currency Rates.1
# 1                 EUR/EUR                       1.0
# 2                 EUR/GBP                   1.13598
# 3                 EUR/USD                   0.69524
# Identifier: 20110729_IPBS_CDS-Senior-Bucket3 - Found 'Auction Currency Rates' in row: EUR/USD
# Identifier: 20110729_IPBS_CDS-Senior-Bucket3 - Exchange rate found: 0.69524
# Identifier: 20110729_IPBS_CDS-Subordinated-Bucket1 - Matching files: ['20110729_IPBS_CDS-Subordinated-Bucket1_Final Results of the Irish Life an_18.csv', '20110729_IPBS_CDS-Subordinated-Bucket1_Final Results of the Irish Life an_19.csv']
# Identifier: 20110729_IPBS_CDS-Subordinated-Bucket1 - Selected CSV file: 20110729_IPBS_CDS-Subordinated-Bucket1_Final Results of the Irish Life an_18.csv
# Identifier: 20110729_IPBS_CDS-Subordinated-Bucket1 - CSV file contents:
#                    0
# 0  Relevant Currency
# 1                EUR
# Identifier: 20110729_IPBS_CDS-Subordinated-Bucket1 - Selected CSV file: 20110729_IPBS_CDS-Subordinated-Bucket1_Final Results of the Irish Life an_19.csv
# Identifier: 20110729_IPBS_CDS-Subordinated-Bucket1 - CSV file contents:
#                         0                         1
# 0  Auction Currency Rates  Auction Currency Rates.1
# 1                 EUR/EUR                       1.0
# 2                 EUR/GBP                   1.13598
# 3                 EUR/USD                   0.69524
# Identifier: 20110729_IPBS_CDS-Subordinated-Bucket1 - Found 'Auction Currency Rates' in row: EUR/USD
# Identifier: 20110729_IPBS_CDS-Subordinated-Bucket1 - Exchange rate found: 0.69524
# Identifier: 20110729_IPBS_CDS-Subordinated-Bucket2 - Matching files: ['20110729_IPBS_CDS-Subordinated-Bucket2_Final Results of the Irish Life an_24.csv', '20110729_IPBS_CDS-Subordinated-Bucket2_Final Results of the Irish Life an_25.csv']
# Identifier: 20110729_IPBS_CDS-Subordinated-Bucket2 - Selected CSV file: 20110729_IPBS_CDS-Subordinated-Bucket2_Final Results of the Irish Life an_24.csv
# Identifier: 20110729_IPBS_CDS-Subordinated-Bucket2 - CSV file contents:
#                    0
# 0  Relevant Currency
# 1                EUR
# Identifier: 20110729_IPBS_CDS-Subordinated-Bucket2 - Selected CSV file: 20110729_IPBS_CDS-Subordinated-Bucket2_Final Results of the Irish Life an_25.csv
# Identifier: 20110729_IPBS_CDS-Subordinated-Bucket2 - CSV file contents:
#                         0                         1
# 0  Auction Currency Rates  Auction Currency Rates.1
# 1                 EUR/EUR                       1.0
# 2                 EUR/GBP                   1.13598
# 3                 EUR/USD                   0.69524
# Identifier: 20110729_IPBS_CDS-Subordinated-Bucket2 - Found 'Auction Currency Rates' in row: EUR/USD
# Identifier: 20110729_IPBS_CDS-Subordinated-Bucket2 - Exchange rate found: 0.69524
# Identifier: 20110729_IPBS_CDS-Subordinated-Bucket3 - Matching files: ['20110729_IPBS_CDS-Subordinated-Bucket3_Final Results of the Irish Life an_30.csv', '20110729_IPBS_CDS-Subordinated-Bucket3_Final Results of the Irish Life an_31.csv']
# Identifier: 20110729_IPBS_CDS-Subordinated-Bucket3 - Selected CSV file: 20110729_IPBS_CDS-Subordinated-Bucket3_Final Results of the Irish Life an_30.csv
# Identifier: 20110729_IPBS_CDS-Subordinated-Bucket3 - CSV file contents:
#                    0
# 0  Relevant Currency
# 1                EUR
# Identifier: 20110729_IPBS_CDS-Subordinated-Bucket3 - Selected CSV file: 20110729_IPBS_CDS-Subordinated-Bucket3_Final Results of the Irish Life an_31.csv
# Identifier: 20110729_IPBS_CDS-Subordinated-Bucket3 - CSV file contents:
#                         0                         1
# 0  Auction Currency Rates  Auction Currency Rates.1
# 1                 EUR/EUR                       1.0
# 2                 EUR/GBP                   1.13598
# 3                 EUR/USD                   0.69524
# Identifier: 20110729_IPBS_CDS-Subordinated-Bucket3 - Found 'Auction Currency Rates' in row: EUR/USD
# Identifier: 20110729_IPBS_CDS-Subordinated-Bucket3 - Exchange rate found: 0.69524
# Identifier: 20111005_IPBS2_CDS-Senior-Bucket-1 - Matching files: ['20111005_IPBS2_CDS-Senior-Bucket-1_Final Results of the Irish Life an_0.csv', '20111005_IPBS2_CDS-Senior-Bucket-1_Final Results of the Irish Life an_1.csv']
# Identifier: 20111005_IPBS2_CDS-Senior-Bucket-1 - Selected CSV file: 20111005_IPBS2_CDS-Senior-Bucket-1_Final Results of the Irish Life an_0.csv
# Identifier: 20111005_IPBS2_CDS-Senior-Bucket-1 - CSV file contents:
#                    0
# 0  Relevant Currency
# 1                EUR
# Identifier: 20111005_IPBS2_CDS-Senior-Bucket-1 - Selected CSV file: 20111005_IPBS2_CDS-Senior-Bucket-1_Final Results of the Irish Life an_1.csv
# Identifier: 20111005_IPBS2_CDS-Senior-Bucket-1 - CSV file contents:
#                         0                         1
# 0  Auction Currency Rates  Auction Currency Rates.1
# 1                 EUR/EUR                       1.0
# 2                 EUR/GBP                   1.16505
# 3                 EUR/USD                   0.75296
# Identifier: 20111005_IPBS2_CDS-Senior-Bucket-1 - Found 'Auction Currency Rates' in row: EUR/USD
# Identifier: 20111005_IPBS2_CDS-Senior-Bucket-1 - Exchange rate found: 0.75296
# Identifier: 20111005_IPBS2_CDS-Senior-Bucket-2 - Matching files: ['20111005_IPBS2_CDS-Senior-Bucket-2_Final Results of the Irish Life an_7.csv', '20111005_IPBS2_CDS-Senior-Bucket-2_Final Results of the Irish Life an_6.csv']
# Identifier: 20111005_IPBS2_CDS-Senior-Bucket-2 - Selected CSV file: 20111005_IPBS2_CDS-Senior-Bucket-2_Final Results of the Irish Life an_7.csv
# Identifier: 20111005_IPBS2_CDS-Senior-Bucket-2 - CSV file contents:
#                         0                         1
# 0  Auction Currency Rates  Auction Currency Rates.1
# 1                 EUR/EUR                       1.0
# 2                 EUR/GBP                   1.16505
# 3                 EUR/USD                   0.75296
# Identifier: 20111005_IPBS2_CDS-Senior-Bucket-2 - Found 'Auction Currency Rates' in row: EUR/USD
# Identifier: 20111005_IPBS2_CDS-Senior-Bucket-2 - Exchange rate found: 0.75296
# Identifier: 20111109_JVC_CDS - Matching files: ['20111109_JVC_CDS_Final Results of the Victor Compan_0.csv', '20111109_JVC_CDS_Final Results of the Victor Compan_1.csv']
# Identifier: 20111109_JVC_CDS - Selected CSV file: 20111109_JVC_CDS_Final Results of the Victor Compan_0.csv
# Identifier: 20111109_JVC_CDS - CSV file contents:
#                    0
# 0  Relevant Currency
# 1                JPY
# Identifier: 20111109_JVC_CDS - Selected CSV file: 20111109_JVC_CDS_Final Results of the Victor Compan_1.csv
# Identifier: 20111109_JVC_CDS - CSV file contents:
#                         0                         1
# 0  Auction Currency Rates  Auction Currency Rates.1
# 1                 JPY/JPY                       1.0
# Identifier: 20111109_JVC_CDS - Found 'Auction Currency Rates' in the last row
# Identifier: 20111109_JVC_CDS - Exchange rate found: 1.0
# Identifier: 20111123_PANRIC_LCDS - Matching files: ['20111123_PANRIC_LCDS_Final Results of the Panrico \xa0LCDS_0.csv', '20111123_PANRIC_LCDS_Final Results of the Panrico \xa0LCDS_1.csv']
# Identifier: 20111123_PANRIC_LCDS - Selected CSV file: 20111123_PANRIC_LCDS_Final Results of the Panrico  LCDS_0.csv
# Identifier: 20111123_PANRIC_LCDS - CSV file contents:
#                    0
# 0  Relevant Currency
# 1                EUR
# Identifier: 20111123_PANRIC_LCDS - Selected CSV file: 20111123_PANRIC_LCDS_Final Results of the Panrico  LCDS_1.csv
# Identifier: 20111123_PANRIC_LCDS - CSV file contents:
#                         0                         1
# 0  Auction Currency Rates  Auction Currency Rates.1
# 1                 EUR/EUR                       1.0
# Identifier: 20111123_PANRIC_LCDS - Found 'Auction Currency Rates' in the last row
# Identifier: 20111123_PANRIC_LCDS - Exchange rate found: 1.0
# Identifier: 20111129_DYNHLD_CDS - Currency is USD or $, exchange rate set to 1
# Identifier: 20111209_SPGIM_CDS - Matching files: ['20111209_SPGIM_CDS_Final Results of the Seat Pagine G_0.csv', '20111209_SPGIM_CDS_Final Results of the Seat Pagine G_1.csv']
# Identifier: 20111209_SPGIM_CDS - Selected CSV file: 20111209_SPGIM_CDS_Final Results of the Seat Pagine G_0.csv
# Identifier: 20111209_SPGIM_CDS - CSV file contents:
#                    0
# 0  Relevant Currency
# 1                EUR
# Identifier: 20111209_SPGIM_CDS - Selected CSV file: 20111209_SPGIM_CDS_Final Results of the Seat Pagine G_1.csv
# Identifier: 20111209_SPGIM_CDS - CSV file contents:
#                         0                         1
# 0  Auction Currency Rates  Auction Currency Rates.1
# 1                 EUR/EUR                       1.0
# Identifier: 20111209_SPGIM_CDS - Found 'Auction Currency Rates' in the last row
# Identifier: 20111209_SPGIM_CDS - Exchange rate found: 1.0
# Identifier: 20111213_PMI_CDS - Currency is USD or $, exchange rate set to 1
# Identifier: 20111215_AMR_CDS - Currency is USD or $, exchange rate set to 1
# Identifier: 20120117_Seat-A05_LCDS - Matching files: ['20120117_Seat-A05_LCDS_Final Results of the SEAT \xa0LCDS Au_0.csv', '20120117_Seat-A05_LCDS_Final Results of the SEAT \xa0LCDS Au_1.csv']
# Identifier: 20120117_Seat-A05_LCDS - Selected CSV file: 20120117_Seat-A05_LCDS_Final Results of the SEAT  LCDS Au_0.csv
# Identifier: 20120117_Seat-A05_LCDS - CSV file contents:
#                    0
# 0  Relevant Currency
# 1                EUR
# Identifier: 20120117_Seat-A05_LCDS - Selected CSV file: 20120117_Seat-A05_LCDS_Final Results of the SEAT  LCDS Au_1.csv
# Identifier: 20120117_Seat-A05_LCDS - CSV file contents:
#                         0                         1
# 0  Auction Currency Rates  Auction Currency Rates.1
# 1                 EUR/EUR                       1.0
# Identifier: 20120117_Seat-A05_LCDS - Found 'Auction Currency Rates' in the last row
# Identifier: 20120117_Seat-A05_LCDS - Exchange rate found: 1.0
# Identifier: 20120202_NRAMC_CDS-Bucket-1 - Matching files: ['20120202_NRAMC_CDS-Bucket-1_Final Results of the Northern Rock_1.csv', '20120202_NRAMC_CDS-Bucket-1_Final Results of the Northern Rock_0.csv']
# Identifier: 20120202_NRAMC_CDS-Bucket-1 - Selected CSV file: 20120202_NRAMC_CDS-Bucket-1_Final Results of the Northern Rock_1.csv
# Identifier: 20120202_NRAMC_CDS-Bucket-1 - CSV file contents:
#                         0                         1
# 0  Auction Currency Rates  Auction Currency Rates.1
# 1                 EUR/EUR                       1.0
# 2                 EUR/GBP                    1.2055
# 3                 EUR/USD                   0.76391
# Identifier: 20120202_NRAMC_CDS-Bucket-1 - Found 'Auction Currency Rates' in row: EUR/USD
# Identifier: 20120202_NRAMC_CDS-Bucket-1 - Exchange rate found: 0.76391
# Identifier: 20120202_NRAMC_CDS-Bucket-2 - Matching files: ['20120202_NRAMC_CDS-Bucket-2_Final Results of the Northern Rock_6.csv', '20120202_NRAMC_CDS-Bucket-2_Final Results of the Northern Rock_7.csv']
# Identifier: 20120202_NRAMC_CDS-Bucket-2 - Selected CSV file: 20120202_NRAMC_CDS-Bucket-2_Final Results of the Northern Rock_6.csv
# Identifier: 20120202_NRAMC_CDS-Bucket-2 - CSV file contents:
#                    0
# 0  Relevant Currency
# 1                EUR
# Identifier: 20120202_NRAMC_CDS-Bucket-2 - Selected CSV file: 20120202_NRAMC_CDS-Bucket-2_Final Results of the Northern Rock_7.csv
# Identifier: 20120202_NRAMC_CDS-Bucket-2 - CSV file contents:
#                         0                         1
# 0  Auction Currency Rates  Auction Currency Rates.1
# 1                 EUR/EUR                       1.0
# 2                 EUR/GBP                    1.2055
# 3                 EUR/USD                   0.76391
# Identifier: 20120202_NRAMC_CDS-Bucket-2 - Found 'Auction Currency Rates' in row: EUR/USD
# Identifier: 20120202_NRAMC_CDS-Bucket-2 - Exchange rate found: 0.76391
# Identifier: 20120222_EK_CDS - Currency is USD or $, exchange rate set to 1
# Identifier: 20120319_GREECE_CDS - Matching files: ['20120319_GREECE_CDS_Final Results of the Hellenic Repu_0.csv', '20120319_GREECE_CDS_Final Results of the Hellenic Repu_1.csv']
# Identifier: 20120319_GREECE_CDS - Selected CSV file: 20120319_GREECE_CDS_Final Results of the Hellenic Repu_0.csv
# Identifier: 20120319_GREECE_CDS - CSV file contents:
#                    0
# 0  Relevant Currency
# 1                EUR
# Identifier: 20120319_GREECE_CDS - Selected CSV file: 20120319_GREECE_CDS_Final Results of the Hellenic Repu_1.csv
# Identifier: 20120319_GREECE_CDS - CSV file contents:
#                         0                         1
# 0  Auction Currency Rates  Auction Currency Rates.1
# 1                 EUR/CHF                   0.82881
# 2                 EUR/EUR                       1.0
# 3                 EUR/GBP                   1.20294
# 4                 EUR/JPY                   0.00911
# ...
# 2          4.100000e+07      USD           1.0             USD/USD
# 3          2.000000e+07      USD           1.0             USD/USD
# 4          7.700000e+07      USD           1.0             USD/USD
# 5          3.050000e+07      USD           1.0             USD/USD
# 6          6.600000e+07      USD           1.0             USD/USD
# 7          6.000000e+07      USD           1.0             USD/USD
# 8          1.200000e+07      USD           1.0             USD/USD
# 9          6.080000e+08      USD           1.0             USD/USD
# 10         7.900000e+07      USD           1.0             USD/USD
# 11         5.420000e+08      USD           1.0             USD/USD
# 12         4.920000e+06      USD           1.0             USD/USD
# 13         9.880000e+08      USD           1.0             USD/USD
# 14         4.540000e+08      EUR           NaN                None
# 15         6.300000e+07      EUR           NaN                None
# 16         1.870000e+08      EUR           NaN                None
# 17         5.500000e+07      EUR           NaN                None
# 18         9.740000e+08      EUR           NaN                None
# 19         1.100000e+07      EUR           NaN                None
# 20         1.800000e+07      USD           1.0             USD/USD
# 21         8.500000e+06      USD           1.0             USD/USD
# 22         7.650000e+08      USD           1.0             USD/USD
# 23         2.000000e+06      USD           1.0             USD/USD
# 24         7.748200e+07      USD           1.0             USD/USD
# 25         3.347600e+07      USD           1.0             USD/USD
# 26         1.432380e+08      USD           1.0             USD/USD
# 27         1.380000e+08      USD           1.0             USD/USD
# 28         1.015000e+07      USD           1.0             USD/USD
# 29         2.000000e+06      EUR           NaN                None
# 30         0.000000e+00      EUR           NaN                None
# 31         1.100000e+07      GBP           NaN                None
# 32         0.000000e+00      GBP           NaN                None
# 33         2.904700e+08      USD           1.0             USD/USD
# 34         1.291600e+07      USD           1.0             USD/USD
# 35         1.286750e+08      USD           1.0             USD/USD
# 36         4.000000e+07      USD           1.0             USD/USD
# 37         0.000000e+00      EUR           NaN                None
# 38         4.000000e+07      USD           1.0             USD/USD
# 39         2.400000e+07      USD           1.0             USD/USD
# 40         9.873800e+07      USD           1.0             USD/USD
# 41         1.306320e+08      USD           1.0             USD/USD
# 42         8.585000e+06      USD           1.0             USD/USD
# 43         9.524500e+07      EUR           NaN                None
# 44         2.342470e+08      USD           1.0             USD/USD
# 45         4.920000e+07      USD           1.0             USD/USD
# 46         4.000000e+07      USD           1.0             USD/USD
# 47         1.150500e+08      USD           1.0             USD/USD
# 48         8.895570e+08      USD           1.0             USD/USD
# 49         1.000000e+07      USD           1.0             USD/USD
# 50         1.175830e+08      USD           1.0             USD/USD
# 51         2.000000e+07      USD           1.0             USD/USD
# 52         2.349240e+08      USD           1.0             USD/USD
# 53         0.000000e+00      EUR           NaN                None
# 54         7.000000e+06      USD           1.0             USD/USD
# 55         1.600000e+07      USD           1.0             USD/USD
# 56         8.090000e+08      USD           1.0             USD/USD
# 57         1.439000e+08      USD           1.0             USD/USD
# 58         5.290980e+08      USD           1.0             USD/USD
# 59         4.600000e+07      USD           1.0             USD/USD
# 60         2.800000e+07      USD           1.0             USD/USD
# 61         1.796770e+08      USD           1.0             USD/USD
# 62         4.000000e+07      USD           1.0             USD/USD
# 63         1.700000e+07      USD           1.0             USD/USD
# 64         1.300000e+07      USD           1.0             USD/USD
# 65         3.700000e+07      USD           1.0             USD/USD
# 66         6.200000e+07      USD           1.0             USD/USD
# 67         1.900000e+07      USD           1.0             USD/USD
# 68         1.725280e+08      USD           1.0             USD/USD
# 69         7.000000e+07      USD           1.0             USD/USD
# 70         1.453340e+08      EUR       1.15995             EUR/GBP
# 71         2.767000e+07      EUR       1.15995             EUR/GBP
# 72         0.000000e+00      GBP          None                None
# 73         8.096700e+07      EUR       0.66921             EUR/USD
# 74         2.206690e+08      EUR       0.66921             EUR/USD
# 75         1.475680e+08      EUR       0.66921             EUR/USD
# 76         2.300000e+07      USD             1             USD/USD
# 77         7.289800e+08      USD             1             USD/USD
# 78         5.749500e+07      EUR       0.67866             EUR/USD
# 79         2.462430e+08      EUR        0.6839             EUR/USD
# 80         1.356450e+08      USD             1             USD/USD
# 81         1.822550e+08      USD             1             USD/USD
# 82         9.042500e+07      USD             1             USD/USD
# 83         1.700000e+07      JPY         90.34             JPY/USD
# 84         0.000000e+00      GBP          None                None
# 85         3.000000e+08      JPY           1.0             JPY/JPY
# 86         3.000980e+08      USD             1             USD/USD
# 87         2.352630e+08      EUR        0.7893             EUR/USD
# 88         0.000000e+00      EUR          None                None
# 89         5.000000e+06      USD             1             USD/USD
# 90         2.120000e+10      JPY         80.72             JPY/USD
# 91         1.040500e+08      EUR       0.74937             EUR/USD
# 92         2.350000e+07      EUR       0.74937             EUR/USD
# 93         2.255000e+07      EUR       0.74937             EUR/USD
# 94         1.125000e+07      EUR       0.74937             EUR/USD
# 95         3.000000e+07      EUR       0.74937             EUR/USD
# 96         4.079050e+08      USD             1             USD/USD
# 97         7.900000e+06      EUR       0.72939             EUR/USD
# 98         2.050000e+06      EUR       0.69662             EUR/USD
# 99         2.265000e+07      EUR       0.69662             EUR/USD
# 100        3.100000e+07      EUR       0.69035             EUR/USD
# 101        1.280000e+07      EUR       0.69035             EUR/USD
# 102        5.150000e+06      EUR       0.69035             EUR/USD
# 103                 NaN      EUR       0.69035             EUR/USD
# 104        3.000000e+06      EUR       0.69035             EUR/USD
# 105        2.800000e+07      EUR       0.69035             EUR/USD
# 106        3.000000e+06      EUR       0.69035             EUR/USD
# 107        2.500000e+07      EUR       0.69524             EUR/USD
# 108        1.160000e+07      EUR       0.69524             EUR/USD
# 109        1.000000e+07      EUR       0.69524             EUR/USD
# 110        1.150000e+07      EUR       0.69524             EUR/USD
# 111                 NaN      EUR       0.69524             EUR/USD
# 112        5.000000e+06      EUR       0.69524             EUR/USD
# 113                 NaN      EUR       0.75296             EUR/USD
# 114        1.000000e+07      EUR       0.75296             EUR/USD
# 115        2.400000e+09      JPY           1.0             JPY/JPY
# 116                 NaN      EUR           1.0             EUR/EUR
# 117        6.115600e+07      USD             1             USD/USD
# 118        6.675000e+07      EUR           1.0             EUR/EUR
# 119        3.755880e+08      USD             1             USD/USD
# 120        1.194850e+08      USD             1             USD/USD
# 121        1.364900e+07      EUR           1.0             EUR/EUR
# 122        1.750000e+07      EUR       0.76391             EUR/USD
# 123        1.100000e+07      EUR       0.76391             EUR/USD
# 124        2.263690e+08      USD             1             USD/USD
# 125        2.916000e+08      EUR       0.75924             EUR/USD
# 126        1.800000e+09      JPY           1.0             JPY/JPY
# 127        5.000000e+06      EUR           1.0             EUR/EUR
# 128        1.233000e+08      EUR           1.0             EUR/EUR
# 129        3.000000e+06      USD             1             USD/USD
# 130        3.900000e+07      EUR           1.0             EUR/EUR
# 131        1.000000e+06      EUR           1.0             EUR/EUR
# 132        3.605000e+07      USD             1             USD/USD
# 133        1.616500e+07      USD             1             USD/USD
# 134        2.903200e+07      USD             1             USD/USD
# 135        1.850000e+07      EUR       0.78345             EUR/USD
# 136        4.118500e+07      USD             1             USD/USD
# 137        6.250000e+06      USD             1             USD/USD
# 138        2.000000e+06      EUR           1.0             EUR/EUR
# 139        1.165000e+07      EUR       0.77909             EUR/USD
# 140        1.300000e+07      EUR       0.77909             EUR/USD
# 141        2.000000e+06      USD           1.0             USD/USD
# 142        2.000000e+06      USD           1.0             USD/USD
# 143        2.100000e+07      EUR           1.0             EUR/EUR
# 144        1.270000e+07      EUR           1.0             EUR/EUR
# 145        7.500000e+06      EUR           1.0             EUR/EUR
# 146        1.000000e+07      EUR           1.0             EUR/EUR
# 147        7.290000e+07      USD             1             USD/USD
# 148        0.000000e+00      USD             1             USD/USD
# 149        1.034500e+08      EUR       0.73695             EUR/USD
# 150        2.000000e+05      USD             1             USD/USD
# 151        0.000000e+00      USD           1.0             USD/USD
# 152        2.394400e+07      USD             1             USD/USD
# 153        1.410000e+08      USD             1             USD/USD
# 154        7.075000e+07      USD             1             USD/USD
# 155        5.000000e+05      EUR           1.0             EUR/EUR
# 156        9.603000e+07      USD             1             USD/USD
# 157        4.909400e+07      USD             1             USD/USD
# 158        3.700000e+07      USD             1             USD/USD
# 159        5.931800e+07      USD             1             USD/USD
# 160        4.683300e+07      USD             1             USD/USD
# 161        4.763800e+07      USD             1             USD/USD
# 162        1.545000e+07      USD             1             USD/USD
# 163        3.294000e+08      EUR        1.0826             USD/EUR
# 164        1.230000e+06      USD             1             USD/USD
# 165        6.526700e+07      USD           1.0             USD/USD
# 166        6.925000e+07      EUR        1.1337             USD/EUR
# 167        3.410000e+07      EUR        1.1337             USD/EUR
# 168        0.000000e+00      EUR        1.1337             USD/EUR
# 169        5.550000e+06      EUR        1.1337             USD/EUR
# 170        8.620000e+07      EUR       0.90794             USD/EUR
# 171        8.265000e+06      USD             1             USD/USD
# 172        5.690000e+07      EUR       1.13295             USD/EUR
# 173        1.819820e+08      USD             1             USD/USD
# 174        0.000000e+00      USD             1             USD/USD
# 175        0.000000e+00      USD           1.0             USD/USD
# 176        6.380500e+07      USD             1             USD/USD
# 177        3.840000e+06      USD             1             USD/USD
# 178        6.925000e+07      EUR       0.83658             USD/EUR
# 179        3.410000e+07      EUR        1.1337             USD/EUR
# 180        0.000000e+00      EUR        1.1337             USD/EUR
# 181        5.550000e+06      EUR        1.1337             USD/EUR
# 182        2.950000e+06      EUR       0.83479             USD/EUR
# 183        1.000000e+07      EUR       0.85074             USD/EUR
# 184        0.000000e+00      EUR       0.85074             USD/EUR
# 185        0.000000e+00      USD             1             USD/USD
# 186        8.117200e+07      USD             1             USD/USD
# 187        5.505000e+07      EUR       0.86003             USD/EUR
# 188        5.500000e+06      EUR       0.86003             USD/EUR
# 189        1.051330e+08      USD             1             USD/USD
# 190        1.059200e+08      USD             1             USD/USD
# 191        6.300000e+06      USD             1             USD/USD
# 192        1.623510e+08      USD             1             USD/USD
# 193        0.000000e+00      EUR       0.83406             USD/EUR
# 194                 NaN      EUR           1.0             EUR/EUR
# 195                 NaN      EUR           1.0             EUR/EUR
# 196        3.740000e+07      EUR        0.8857             USD/EUR
# 197        4.493600e+07      USD             1             USD/USD
# 198        4.739700e+07      USD             1             USD/USD
# 199        2.080000e+07      USD             1             USD/USD
# 200        6.820400e+07      USD             1             USD/USD
# 201        5.880000e+07      EUR       1.13106             EUR/GBP
# 202        1.671500e+08      EUR           1.0             EUR/EUR
# 203        9.331200e+07      USD             1             USD/USD
# 204        1.440000e+07      EUR           1.0             EUR/EUR
# 205        0.000000e+00      EUR          None                None
# 206        8.400000e+06      EUR       0.90934             EUR/USD
# 207        1.717000e+08      EUR           1.0             EUR/EUR
# 208        1.809860e+08      USD             1             USD/USD
# 209        6.256300e+07      USD             1             USD/USD
# 210        1.087000e+08      USD             1             USD/USD
# 211        1.927730e+08      USD             1             USD/USD
# 212        1.166310e+08      USD             1             USD/USD
# 213        2.728200e+07      USD             1             USD/USD
# 214        1.765850e+08      USD             1             USD/USD
# 215        1.787110e+08      USD             1             USD/USD
# 216        0.000000e+00      USD             1             USD/USD
# 217        3.521170e+08      USD             1             USD/USD
# 218        3.108860e+08      USD             1             USD/USD
# 219        1.115250e+08      USD             1             USD/USD
# 220        6.904300e+07      USD             1             USD/USD
# 221        5.010000e+07      EUR           1.0             EUR/EUR
# 222        2.656260e+08      USD             1             USD/USD
# 223        4.400000e+06      EUR           1.0             EUR/EUR
# 224        1.115850e+08      USD             1             USD/USD
# 225        1.150000e+07      GBP           1.0             GBP/GBP
# 226        4.775000e+07      GBP           1.0             GBP/GBP
# 227        7.800000e+06      EUR           1.0             EUR/EUR
# 228        4.330000e+07      EUR           1.0             EUR/EUR
# 229        1.060480e+08      USD             1             USD/USD
# 230        5.024000e+08      USD             1             USD/USD
# 231        4.100000e+07      USD             1             USD/USD
# 232        4.470000e+07      USD             1             USD/USD

# %%
# Replace the null values in currency_exchange with the combination of currency1/currency2
data['currencies_exchange'].fillna(data['currency'] + '/' + data['currency'], inplace=True)

# %%
# Set the exchange rate to 1 for the rows where currency_exchange is None
data.loc[data['exchange_rate'].isnull(), 'exchange_rate'] = 1

# %%
data[data['exchange_rate'].isnull()]
# Out:
# Empty DataFrame
# Columns: [identifier, auction_name, date, ticker, box_title, multiple_final_prices, final_price, IMM, NOI, noi_absolute_value, noi_direction, currency, exchange_rate, currencies_exchange]
# Index: []

# %%
from currency_converter import CurrencyConverter
from dateutil import parser

# Create an instance of CurrencyConverter
c = CurrencyConverter()

# Function to get the exchange rate from USD to a specific currency on a given date
def get_exchange_rate(date, currency):
    return c.convert(1, 'USD', currency, date=date)

# Iterate over each row of the dataset
for index, row in data.iterrows():
    currency = row['currency']
    currencies_exchange = row['currencies_exchange']
    date_str = row['date']

    # Parse the date string into a datetime object
    date = parser.parse(date_str).date()

    # Check if the currency is not USD and 'USD' is not present in currencies_exchange
    if currency != 'USD': #and not re.search(r'USD', currencies_exchange)
        # Get the exchange rate from USD to the specific currency on the given date
        exchange_rate = get_exchange_rate(date, currency)
        currencies_exchange = 'USD/' + currency

        # Update the exchange_rate and currencies_exchange columns
        data.at[index, 'exchange_rate'] = exchange_rate
        data.at[index, 'currencies_exchange'] = currencies_exchange
    # Convert 'noi_absolute_value' to USD
    data.at[index, 'noi_usd'] = row['noi_absolute_value'] / exchange_rate

        
# Print the updated DataFrame
print(data)
# Out:
#                                      identifier  \
# 0                           20051104_delphi_CDS
# 1                          20060117_calpine_CDS
# 2                 20060331_dana_corporation_CDS
# 3                      20061128_dura_senior_CDS
# 4                20061128_dura_subordinated_CDS
# 5                   20071023_movie_gallery_LCDS
# 6                           20080219_quebcr_CDS
# 7                           20081002_tembec_CDS
# 8           20081006_famefrmc_Fannie-Mae-Senior
# 9     20081006_famefrmc_Fannie-Mae-Subordinated
# 10         20081006_famefrmc_Freddie-Mac-Senior
# 11   20081006_famefrmc_Freddie-Mac-Subordinated
# 12                          20081010_lehbro_CDS
# 13                          20081023_washmu_CDS
# 14                       20081104_landsb_Senior
# 15                 20081104_landsb_Subordinated
# 16                       20081105_glitni_Senior
# 17                 20081105_glitni_Subordinated
# 18                       20081106_kaupth_Senior
# 19                 20081106_kaupth_Subordinated
# 20                          20081209_masoni_CDS
# 21                          20081217_hawtel_CDS
# 22                          20090106_tribco_CDS
# 23                         20090106_tribco_LCDS
# 24                          20090114_ecuado_CDS
# 25                          20090203_equstr_CDS
# 26                          20090203_lyodel_CDS
# 27                         20090203_lyodel_LCDS
# 28                          20090203_millen_CDS
# 29                     20090205_sanitc_1st-Lien
# 30                     20090205_sanitc_2nd-Lien
# 31                         20090209_br_1st-Lien
# 32                         20090209_br_2nd-Lien
# 33                          20090210_norcor_CDS
# 34                          20090210_norltd_CDS
# 35                          20090219_smurfs_CDS
# 36                         20090219_smurfs_LCDS
# 37                         20090226_fereti_LCDS
# 38                         20090309_aleris_LCDS
# 39                          20090331_stncas_CDS
# 40                          20090414_chmtra_CDS
# 41                          20090414_grtlak_CDS
# 42                           20090415_rouse_CDS
# 43                          20090416_lyobas_CDS
# 44                          20090417_abitbi_CDS
# 45                          20090421_chacom_CDS
# 46                         20090421_chacom_LCDS
# 47                          20090422_capmrk_CDS
# 48                          20090423_idearc_CDS
# 49                         20090423_idearc_LCDS
# 50                          20090512_bowatr_CDS
# 51                         20090513_gegrpr_LCDS
# 52                          20090527_syncra_CDS
# 53                         20090528_edscha_LCDS
# 54                          20090609_hliop_LCDS
# 55                         20090610_geguco_LCDS
# 56                          20090610_jscbta_CDS
# 57                          20090611_rhdcor_CDS
# 58                          20090612_genmtr_CDS
# 59                         20090612_genmtr_LCDS
# 60                          20090618_jscali_CDS
# 61                          20090623_viston_CDS
# 62                         20090623_viston_LCDS
# 63                         20090624_dexest_LCDS
# 64                         20090624_dexwst_LCDS
# 65                         20090624_rhdltd_LCDS
# 66                          20090709_sixflg_CDS
# 67                         20090709_sixflg_LCDS
# 68                          20090721_leacor_CDS
# 69                         20090721_leacor_LCDS
# 70                       20090730_brabin_Senior
# 71                 20090730_brabin_Subordinated
# 72                         20091008_sspflt_LCDS
# 73     20091022_thmbrd_2.5-year-maturity-bucket
# 74       20091022_thmbrd_5-year-maturity-bucket
# 75     20091022_thmbrd_7.5-year-maturity-bucket
# 76                         20091110_mgminc_LCDS
# 77                          20091120_citgrp_CDS
# 78                          20091210_thomsn_CDS
# 79             20091215_hellas_CDS-Subordinated
# 80                          20091216_nafukr_CDS
# 81                            20100107_fgic_CDS
# 82                           20100218_cemex_CDS
# 83                           20100325_aiful_CDS
# 84                   20100415_carstn_LCDS-LIEN1
# 85                          20100422_jalcor_CDS
# 86                   20100604_ABK-AssurCorp_CDS
# 87                     20100715_TRUVO-SubCo_CDS
# 88                   20100909_WorldDir-B07_LCDS
# 89                           20100921_BOSG_LCDS
# 90                          20101028_TAKFUJ_CDS
# 91       20101209_ANGBKL_CDS-SNR-or-SUB-Bucket1
# 92           20101209_ANGBKL_CDS-Senior-Bucket2
# 93           20101209_ANGBKL_CDS-Senior-Bucket3
# 94     20101209_ANGBKL_CDS-Subordinated-Bucket2
# 95     20101209_ANGBKL_CDS-Subordinated-Bucket3
# 96                             20101210_ABK_CDS
# 97       20110202_ANGBKL2_CDS-25-years-maturity
# 98                      20110630_AIB_CDS-Senior
# 99                20110630_AIB_CDS-Subordinated
# 100        20110728_BKIR_CDS-SNR-or-SUB-Bucket1
# 101            20110728_BKIR_CDS-Senior-Bucket2
# 102            20110728_BKIR_CDS-Senior-Bucket3
# 103            20110728_BKIR_CDS-Senior-Bucket6
# 104      20110728_BKIR_CDS-Subordinated-Bucket2
# 105      20110728_BKIR_CDS-Subordinated-Bucket3
# 106      20110728_BKIR_CDS-Subordinated-Bucket6
# 107            20110729_IPBS_CDS-Senior-Bucket1
# 108            20110729_IPBS_CDS-Senior-Bucket2
# 109            20110729_IPBS_CDS-Senior-Bucket3
# 110      20110729_IPBS_CDS-Subordinated-Bucket1
# 111      20110729_IPBS_CDS-Subordinated-Bucket2
# 112      20110729_IPBS_CDS-Subordinated-Bucket3
# 113          20111005_IPBS2_CDS-Senior-Bucket-1
# 114          20111005_IPBS2_CDS-Senior-Bucket-2
# 115                            20111109_JVC_CDS
# 116                        20111123_PANRIC_LCDS
# 117                         20111129_DYNHLD_CDS
# 118                          20111209_SPGIM_CDS
# 119                            20111213_PMI_CDS
# 120                            20111215_AMR_CDS
# 121                      20120117_Seat-A05_LCDS
# 122                 20120202_NRAMC_CDS-Bucket-1
# 123                 20120202_NRAMC_CDS-Bucket-2
# 124                             20120222_EK_CDS
# 125                         20120319_GREECE_CDS
# 126                  20120322_HITACH-Elpida_CDS
# 127                         20120328_FCGIA_LCDS
# 128                         20120329_ERCIFT_CDS
# 129                  20120426_HAWKER-Acqui_LCDS
# 130            20120502_ELCDS-Eircom_LCDS-LIEN1
# 131            20120502_ELCDS-Eircom_LCDS-LIEN2
# 132                           20120509_SIFO_CDS
# 133                         20120530_HTNMIF_CDS
# 134                     20120606_GM-ResCLLC_CDS
# 135              20121115_ELCDS-Yell_LCDS-LIEN1
# 136                            20121206_OSG_CDS
# 137                20130116_EIX-EdMisEnergy_CDS
# 138                      20130131_PJHOLDCO_LCDS
# 139              20130404_SNSBNK_CDS-SNR-or-SUB
# 140     20130404_SNSBNK_CDS-SNR-or-SUB-Bucket-1
# 141                          20130424_DXMI_LCDS
# 142                          20130424_SPMD_LCDS
# 143              20130605_BANKSA_CDS-SNR-or-SUB
# 144     20130605_BANKSA_CDS-SNR-or-SUB-Bucket-1
# 145     20130605_BANKSA_CDS-SNR-or-SUB-Bucket-2
# 146     20130605_BANKSA_CDS-SNR-or-SUB-Bucket-3
# 147                         20130606_URBISA_CDS
# 148                        20130806_CENGLQ_LCDS
# 149                      20131009_CODSA-Fin_CDS
# 150                         20131204_OGXPET_CDS
# 151                        20140521_ENERFUT_CDS
# 152                        20140521_ENERGFU_CDS
# 153          20140521_TXU-Texas-LCDS_LCDS-LIEN1
# 154                      20140521_TXU-Texas_CDS
# 155                       20140819_SOLOGRO_LCDS
# 156                         20140903_ARGENT_CDS
# 157                         20150219_CESEOP_CDS
# 158                        20150219_CESEOP_LCDS
# 159                            20150305_RSH_CDS
# 160                        20150623_SABINOI_CDS
# 161                           20150917_AAHI_CDS
# 162                         20151006_UKRAIN_CDS
# 163                           20160114_ABNG_CDS
# 164                        20160406_PACIEXP_CDS
# 165                         20160504_PLCOAL_CDS
# 166                          20160622_NSINO_CDS
# 167                   20160622_NSINO_CDS-Bucket
# 168                 20160622_NSINO_CDS-Bucket-3
# 169                 20160622_NSINO_CDS-Bucket-4
# 170                  20160721_PLTMPL-IntFin_CDS
# 171                         20160817_CMNWPR_CDS
# 172                        20160824_GRUPOIS_CDS
# 173                        20170202_IHEAINC_CDS
# 174                       20170202_IHEAINC_LCDS
# 175                            20170301_AV_LCDS
# 176                        20170711_GENOENE_CDS
# 177                          20170802_PREPA_CDS
# 178                          20170914_NSINO_CDS
# 179                   20170914_NSINO_CDS-Bucket
# 180                 20170914_NSINO_CDS-Bucket-3
# 181                 20170914_NSINO_CDS-Bucket-4
# 182                     20170921_MONTE_CDS-2014
# 183            20171005_BPESP_CDS-2003-Bucket-1
# 184            20171005_BPESP_CDS-2003-Bucket-2
# 185                          20171011_TOYS_LCDS
# 186                     20171011_TOY_CDS-Senior
# 187            20171101_MONTE_CDS-2003-Bucket-1
# 188            20171101_MONTE_CDS-2003-Bucket-2
# 189                           20171212_VENZ_CDS
# 190                            20171213_PDV_CDS
# 191                          20180425_NBLGP_CDS
# 192                        20180425_NINEWES_CDS
# 193                 20180502_NOVOBAN_CDS-Bucket
# 194              20180906_BPESP_CDS-Subordinate
# 195                 20181127_NOVOBAN_CDS-Senior
# 196                           20181129_ASTL_CDS
# 197                 20190117_SHC-Acceptance_CDS
# 198                            20190123_PKD_CDS
# 199                  20190227_PCGPacGasElec_CDS
# 200                        20190403_WINDSSE_CDS
# 201                       20190605_NEWLOOAC_CDS
# 202                           20190627_GENP_CDS
# 203                     20190724_WFT_CDS-Senior
# 204                        20190807_GALAPHO_CDS
# 205                   20190911_TOGUN_CDS-Senior
# 206                        20190925_STEIEUR_CDS
# 207                    20191030_THCP_CDS-Senior
# 208                         20191210_DNSFDS_CDS
# 209                         20200310_MCLTHY_CDS
# 210                          20200423_LEBAN_CDS
# 211                   20200506_WHPEC_CDS-Senior
# 212                    20200513_FRCA_CDS-Senior
# 213                           20200519_ECUA_CDS
# 214                      20200522_DO_CDS-Senior
# 215                         20200529_THENEI_CDS
# 216                         20200604_INTINV_CDS
# 217                     20200609_JCP_CDS-Senior
# 218                         20200612_ARGENT_CDS
# 219                        20200624_F-Hertz_CDS
# 220                        20200707_CALIRES_CDS
# 221                         20200729_WIREAG_CDS
# 222                            20200804_CHK_CDS
# 223                        20200908_HEMABON_CDS
# 224                             20200910_NE_CDS
# 225                        20200915_MATAFIN_CDS
# 226                        20201001_PIZZAFI_CDS
# 227                        20201020_SELEGRO_CDS
# 228                        20210113_EUROPMO_CDS
# 229                        20220607_TALEENE_CDS
# 230                         20220912_RUSSIA_CDS
# 231                         20220928_UKRAIN_CDS
# 232                        20230413_DIAMSPO_CDS
#
#                                           auction_name                date  \
# 0                                               Delphi   4th November 2005
# 1                                              Calpine   17th January 2006
# 2                                     Dana Corporation     31st March 2006
# 3                                          Dura Senior   November 28, 2006
# 4                                    Dura Subordinated  28th November 2006
# 5                                        Movie Gallery    October 23, 2007
# 6                                             Quebecor  19th February 2008
# 7                                               Tembec    2nd October 2008
# 8                           Fannie Mae and Freddie Mac    6th October 2008
# 9                           Fannie Mae and Freddie Mac    6th October 2008
# 10                          Fannie Mae and Freddie Mac    6th October 2008
# 11                          Fannie Mae and Freddie Mac    6th October 2008
# 12                                     Lehman Brothers   10th October 2008
# 13                                   Washington Mutual   23rd October 2008
# 14                                          Landsbanki   4th November 2008
# 15                                          Landsbanki   4th November 2008
# 16                                             Glitnir   5th November 2008
# 17                                             Glitnir   5th November 2008
# 18                                      Kaupthing Bank   6th November 2008
# 19                                      Kaupthing Bank   6th November 2008
# 20                                            Masonite   9th December 2008
# 21                                     Hawaiian Telcom  17th December 2008
# 22                                             Tribune    6th January 2009
# 23                                             Tribune    6th January 2009
# 24                                             Ecuador   14th January 2009
# 25                                            Equistar   3rd February 2009
# 26                                            Lyondell   3rd February 2009
# 27                                            Lyondell   3rd February 2009
# 28                                          Millennium   3rd February 2009
# 29                                             Sanitec   5th February 2009
# 30                                             Sanitec   5th February 2009
# 31                                        British Vita   9th February 2009
# 32                                        British Vita   9th February 2009
# 33                                         Nortel Corp  10th February 2009
# 34                                         Nortel Ltd.  10th February 2009
# 35                                       Smurfit-Stone  19th February 2009
# 36                                       Smurfit-Stone  19th February 2009
# 37                                            Ferretti  26th February 2009
# 38                                              Aleris      9th March 2009
# 39                                     Station Casinos     31st March 2009
# 40                                            Chemtura     14th April 2009
# 41                                         Great Lakes     14th April 2009
# 42                                               Rouse     15th April 2009
# 43                                      LyondellBasell     16th April 2009
# 44                                             Abitibi     17th April 2009
# 45                              Charter Communications     21st April 2009
# 46                              Charter Communications     21st April 2009
# 47                                             Capmark     22nd April 2009
# 48                                              Idearc     23rd April 2009
# 49                                              Idearc     23rd April 2009
# 50                                             Bowater       12th May 2009
# 51                           General Growth Properties       13th May 2009
# 52                                             Syncora       27th May 2009
# 53                                              Edscha       28th May 2009
# 54                               HLI Operating Company       9th June 2009
# 55                                        Georgia Gulf      10th June 2009
# 56                                        JSC BTA Bank      10th June 2009
# 57                                R.H. Donnelley Corp.      11th June 2009
# 58                                      General Motors      12th June 2009
# 59                                      General Motors      12th June 2009
# 60                                   JSC Alliance Bank      18th June 2009
# 61                                             Visteon      23rd June 2009
# 62                                             Visteon      23rd June 2009
# 63                                      Dex Media East      24th June 2009
# 64                                      Dex Media West      24th June 2009
# 65                                 R.H. Donnelley Inc.      24th June 2009
# 66                                           Six Flags       9th July 2009
# 67                                           Six Flags       9th July 2009
# 68                                           Lear Corp      21st July 2009
# 69                                           Lear Corp      21st July 2009
# 70                                  Bradford & Bingley      30th July 2009
# 71                                  Bradford & Bingley      30th July 2009
# 72                                                 SSP    8th October 2009
# 73                                             Thomson   22nd October 2009
# 74                                             Thomson   22nd October 2009
# 75                                             Thomson   22nd October 2009
# 76                                                 MGM  10th November 2009
# 77                                                 CIT  20th November 2009
# 78                               Thomson  (Bankruptcy)  10th December 2009
# 79                                           Hellas II  15th December 2009
# 80                            NJSC Naftogaz of Ukraine  16th December 2009
# 81         Financial Guaranty Insurance Company (FGIC)      7 January 2010
# 82                                               CEMEX    18 February 2010
# 83                                               Aiful       25 March 2010
# 84                                  McCarthy and Stone       15 April 2010
# 85                          Japan Airlines Corporation       22 April 2010
# 86                                Ambac Assurance Corp        04 June 2010
# 87                               Truvo Subsidiary Corp        15 July 2010
# 88         Truvo (formerly known as World Directories)   09 September 2010
# 89                              Boston Generating, LLC   21 September 2010
# 90                                       Takefuji Corp     28 October 2010
# 91                                    Anglo Irish Bank    09 December 2010
# 92                                    Anglo Irish Bank    09 December 2010
# 93                                    Anglo Irish Bank    09 December 2010
# 94                                    Anglo Irish Bank    09 December 2010
# 95                                    Anglo Irish Bank    09 December 2010
# 96                               Ambac Financial Group    10 December 2010
# 97   Anglo Irish Bank Corporation Limited Credit Ev...    02 February 2011
# 98                                Allied Irish Bks PLC        30 June 2011
# 99                                Allied Irish Bks PLC        30 June 2011
# 100    The Governor and Company of the Bank of Ireland        28 July 2011
# 101    The Governor and Company of the Bank of Ireland        28 July 2011
# 102    The Governor and Company of the Bank of Ireland        28 July 2011
# 103    The Governor and Company of the Bank of Ireland        28 July 2011
# 104    The Governor and Company of the Bank of Ireland        28 July 2011
# 105    The Governor and Company of the Bank of Ireland        28 July 2011
# 106    The Governor and Company of the Bank of Ireland        28 July 2011
# 107                           Irish Life and Permanent        29 July 2011
# 108                           Irish Life and Permanent        29 July 2011
# 109                           Irish Life and Permanent        29 July 2011
# 110                           Irish Life and Permanent        29 July 2011
# 111                           Irish Life and Permanent        29 July 2011
# 112                           Irish Life and Permanent        29 July 2011
# 113    Irish Life and Permanent - August Restructuring     05 October 2011
# 114    Irish Life and Permanent - August Restructuring     05 October 2011
# 115                            Victor Company of Japan    09 November 2011
# 116                                            Panrico    23 November 2011
# 117                               Dynegy Holdings, LLC    29 November 2011
# 118                                 Seat Pagine Gialle    09 December 2011
# 119                                          PMI Group    13 December 2011
# 120                                           AMR Corp    15 December 2011
# 121                                               SEAT     17 January 2012
# 122               Northern Rock (Asset Management) plc    02 February 2012
# 123               Northern Rock (Asset Management) plc    02 February 2012
# 124                                   Eastman Kodak Co    22 February 2012
# 125                                  Hellenic Republic       19 March 2012
# 126                                      Elpida Memory       22 March 2012
# 127                               Financiere Gaillon 7       28 March 2012
# 128                                ERC Ireland Fin Ltd       29 March 2012
# 129               Hawker Beechcraft Acquisition Co LLC       26 April 2012
# 130                                             Eircom         02 May 2012
# 131                                             Eircom         02 May 2012
# 132                                   Sino Forest Corp         09 May 2012
# 133            Houghton Mifflin Harcourt Publishing Co         30 May 2012
# 134                                Residential Cap LLC        06 June 2012
# 135                                       Yell Limited    15 November 2012
# 136                     OVERSEAS SHIPHOLDING GROUP INC    06 December 2012
# 137                              Edison Mission Energy     16 January 2013
# 138                                       Mediannuaire     31 January 2013
# 139                                        SNS Bank NV       04 April 2013
# 140                                        SNS Bank NV       04 April 2013
# 141                               Dex Media West, Inc.       24 April 2013
# 142                                    SuperMedia Inc.       24 April 2013
# 143                                             Bankia        05 June 2013
# 144                                             Bankia        05 June 2013
# 145                                             Bankia        05 June 2013
# 146                                             Bankia        05 June 2013
# 147  Urbi Desarrollos Urbanos S A Bursatil de Cap V...        06 June 2013
# 148                  Cengage Learning Acquisitions Inc      06 August 2013
# 149                           CODERE Fin LUXEMBOURG SA     09 October 2013
# 150                OGX PETROLEO E GAS PARTICIPACOES SA    04 December 2013
# 151  Energy Future Intermediate Holding Company LLC...         21 May 2014
# 152                       Energy Future Holdings Corp.         21 May 2014
# 153  Texas Competitive Electric Holdings Company LL...         21 May 2014
# 154    Texas Competitive Electric Holdings Company LLC         21 May 2014
# 155  Solocal Group S.A. (formerly known as PagesJau...      19 August 2014
# 156                                 Argentine Republic   03 September 2014
# 157                          Caesars Entmt Oper Co Inc    19 February 2015
# 158                          Caesars Entmt Oper Co Inc    19 February 2015
# 159                                    RadioShack Corp       05 March 2015
# 160                                Sabine Oil Gas Corp        23 June 2015
# 161                         Alpha Appalachia Hldgs Inc   17 September 2015
# 162                                            Ukraine     06 October 2015
# 163                                         ABENGOA SA     14 January 2016
# 164                           PACIFIC EXPL PRODTN CORP       06 April 2016
# 165                                  Peabody Engy Corp         04 May 2016
# 166                          Norske Skogindustrier ASA        22 June 2016
# 167                          Norske Skogindustrier ASA        22 June 2016
# 168                          Norske Skogindustrier ASA        22 June 2016
# 169                          Norske Skogindustrier ASA        22 June 2016
# 170        Portugal Telecom International Finance B.V.        21 July 2016
# 171                        Commonwealth of Puerto Rico      17 August 2016
# 172                   Grupo Isolux Corsan Finance B.V.      24 August 2016
# 173                           iHeartCommunications Inc    02 February 2017
# 174                           iHeartCommunications Inc    02 February 2017
# 175                                          Avaya Inc       01 March 2017
# 176                                   GenOn Energy Inc        11 July 2017
# 177               Puerto Rico Electric Power Authority      02 August 2017
# 178                          Norske Skogindustrier ASA   14 September 2017
# 179                          Norske Skogindustrier ASA   14 September 2017
# 180                          Norske Skogindustrier ASA   14 September 2017
# 181                          Norske Skogindustrier ASA   14 September 2017
# 182                Bca Monte dei Paschi di Siena S p A   21 September 2017
# 183                           Banco Popular Español SA     05 October 2017
# 184                           Banco Popular Español SA     05 October 2017
# 185                             TOYS R US DELAWARE INC     11 October 2017
# 186                                      TOYS R US INC     11 October 2017
# 187                Bca Monte dei Paschi di Siena S p A    01 November 2017
# 188                Bca Monte dei Paschi di Siena S p A    01 November 2017
# 189                   Bolivarian Republic of Venezuela    12 December 2017
# 190                       Petróleos de Venezuela, S.A.    13 December 2017
# 191                                    Noble Group Ltd       25 April 2018
# 192                                Nine West Hldgs Inc       25 April 2018
# 193                 NOVO BCO SA (Non-SRO Transactions)         02 May 2018
# 194                           Banco Popular Español SA   06 September 2018
# 195         NOVO BCO SA (senior SRO transactions only)    27 November 2018
# 196                               ASTALDI S per Azioni    29 November 2018
# 197                           Sears Roebuck Accep Corp     17 January 2019
# 198                                 Parker Drilling Co     23 January 2019
# 199                                  Pac Gas & Elec Co    27 February 2019
# 200                            Windstream Services LLC       03 April 2019
# 201                             NEW LOOK SR ISSUER PLC        05 June 2019
# 202                                             Rallye        27 June 2019
# 203                                Weatherford Itl Ltd        24 July 2019
# 204                                  Galapagos Hldg SA      07 August 2019
# 205                        TOP GUN REALISATIONS 61 LTD   11 September 2019
# 206                                STEINHOFF EUROPE AG   25 September 2019
# 207                              THOMAS COOK GROUP PLC     30 October 2019
# 208                                      Dean Foods Co    10 December 2019
# 209                                       McClatchy Co       10 March 2020
# 210                                       Lebanese Rep       23 April 2020
# 211                             Whiting Petroleum Corp         06 May 2020
# 212                                Frontier Comms Corp         13 May 2020
# 213                                     Rep of Ecuador         19 May 2020
# 214                      Diamond Offshore Drilling Inc         22 May 2020
# 215                            Neiman Marcus Group LLC         29 May 2020
# 216                                  Intelsat Invts SA        04 June 2020
# 217                                  J C Penney Co Inc        09 June 2020
# 218                                      Argentine Rep        12 June 2020
# 219                                         HERTZ CORP        24 June 2020
# 220                                        CA RES CORP        07 July 2020
# 221                                        Wirecard AG        29 July 2020
# 222                               Chesapeake Engy Corp      04 August 2020
# 223                                   HEMA BondCo I BV   08 September 2020
# 224                                         Noble Corp   10 September 2020
# 225                                    MATALAN FIN PLC   15 September 2020
# 226                            Pizzaexpress Fing 1 PLC     01 October 2020
# 227                                   Selecta Group BV     20 October 2020
# 228                            Europcar Mobility Group     13 January 2021
# 229                            Talen Energy Supply LLC        07 June 2022
# 230                                       Russian Fedn   12 September 2022
# 231                                            Ukraine   28 September 2022
# 232                           DIAMOND SPORTS GROUP LLC       13 April 2023
#
#                 ticker                 box_title  multiple_final_prices  \
# 0               delphi                       CDS                  False
# 1              calpine                       CDS                  False
# 2     dana_corporation                       CDS                  False
# 3          dura_senior                       CDS                  False
# 4    dura_subordinated                       CDS                  False
# 5        movie_gallery                      LCDS                  False
# 6               quebcr                       CDS                  False
# 7               tembec                       CDS                  False
# 8             famefrmc         Fannie-Mae-Senior                   True
# 9             famefrmc   Fannie-Mae-Subordinated                   True
# 10            famefrmc        Freddie-Mac-Senior                   True
# 11            famefrmc  Freddie-Mac-Subordinated                   True
# 12              lehbro                       CDS                  False
# 13              washmu                       CDS                  False
# 14              landsb                    Senior                   True
# 15              landsb              Subordinated                   True
# 16              glitni                    Senior                   True
# 17              glitni              Subordinated                   True
# 18              kaupth                    Senior                   True
# 19              kaupth              Subordinated                   True
# 20              masoni                       CDS                  False
# 21              hawtel                       CDS                  False
# 22              tribco                       CDS                   True
# 23              tribco                      LCDS                   True
# 24              ecuado                       CDS                  False
# 25              equstr                       CDS                  False
# 26              lyodel                       CDS                   True
# 27              lyodel                      LCDS                   True
# 28              millen                       CDS                  False
# 29              sanitc                  1st-Lien                   True
# 30              sanitc                  2nd-Lien                   True
# 31                  br                  1st-Lien                   True
# 32                  br                  2nd-Lien                   True
# 33              norcor                       CDS                  False
# 34              norltd                       CDS                  False
# 35              smurfs                       CDS                   True
# 36              smurfs                      LCDS                   True
# 37              fereti                      LCDS                  False
# 38              aleris                      LCDS                  False
# 39              stncas                       CDS                  False
# 40              chmtra                       CDS                  False
# 41              grtlak                       CDS                  False
# 42               rouse                       CDS                  False
# 43              lyobas                       CDS                  False
# 44              abitbi                       CDS                  False
# 45              chacom                       CDS                   True
# 46              chacom                      LCDS                   True
# 47              capmrk                       CDS                  False
# 48              idearc                       CDS                   True
# 49              idearc                      LCDS                   True
# 50              bowatr                       CDS                  False
# 51              gegrpr                      LCDS                  False
# 52              syncra                       CDS                  False
# 53              edscha                      LCDS                  False
# 54               hliop                      LCDS                  False
# 55              geguco                      LCDS                  False
# 56              jscbta                       CDS                  False
# 57              rhdcor                       CDS                  False
# 58              genmtr                       CDS                   True
# 59              genmtr                      LCDS                   True
# 60              jscali                       CDS                  False
# 61              viston                       CDS                   True
# 62              viston                      LCDS                   True
# 63              dexest                      LCDS                  False
# 64              dexwst                      LCDS                  False
# 65              rhdltd                      LCDS                  False
# 66              sixflg                       CDS                   True
# 67              sixflg                      LCDS                   True
# 68              leacor                       CDS                   True
# 69              leacor                      LCDS                   True
# 70              brabin                    Senior                   True
# 71              brabin              Subordinated                   True
# 72              sspflt                      LCDS                  False
# 73              thmbrd  2.5-year-maturity-bucket                   True
# 74              thmbrd    5-year-maturity-bucket                   True
# 75              thmbrd  7.5-year-maturity-bucket                   True
# 76              mgminc                      LCDS                  False
# 77              citgrp                       CDS                  False
# 78              thomsn                       CDS                  False
# 79              hellas          CDS-Subordinated                  False
# 80              nafukr                       CDS                  False
# 81                fgic                       CDS                   True
# 82               cemex                       CDS                   True
# 83               aiful                       CDS                   True
# 84              carstn                LCDS-LIEN1                   True
# 85              jalcor                       CDS                   True
# 86       ABK-AssurCorp                       CDS                  False
# 87         TRUVO-SubCo                       CDS                  False
# 88        WorldDir-B07                      LCDS                  False
# 89                BOSG                      LCDS                  False
# 90              TAKFUJ                       CDS                  False
# 91              ANGBKL    CDS-SNR-or-SUB-Bucket1                   True
# 92              ANGBKL        CDS-Senior-Bucket2                   True
# 93              ANGBKL        CDS-Senior-Bucket3                   True
# 94              ANGBKL  CDS-Subordinated-Bucket2                   True
# 95              ANGBKL  CDS-Subordinated-Bucket3                   True
# 96                 ABK                       CDS                  False
# 97             ANGBKL2     CDS-25-years-maturity                  False
# 98                 AIB                CDS-Senior                   True
# 99                 AIB          CDS-Subordinated                   True
# 100               BKIR    CDS-SNR-or-SUB-Bucket1                   True
# 101               BKIR        CDS-Senior-Bucket2                   True
# 102               BKIR        CDS-Senior-Bucket3                   True
# 103               BKIR        CDS-Senior-Bucket6                   True
# 104               BKIR  CDS-Subordinated-Bucket2                   True
# 105               BKIR  CDS-Subordinated-Bucket3                   True
# 106               BKIR  CDS-Subordinated-Bucket6                   True
# 107               IPBS        CDS-Senior-Bucket1                   True
# 108               IPBS        CDS-Senior-Bucket2                   True
# 109               IPBS        CDS-Senior-Bucket3                   True
# 110               IPBS  CDS-Subordinated-Bucket1                   True
# 111               IPBS  CDS-Subordinated-Bucket2                   True
# 112               IPBS  CDS-Subordinated-Bucket3                   True
# 113              IPBS2       CDS-Senior-Bucket-1                   True
# 114              IPBS2       CDS-Senior-Bucket-2                   True
# 115                JVC                       CDS                  False
# 116             PANRIC                      LCDS                  False
# 117             DYNHLD                       CDS                  False
# 118              SPGIM                       CDS                  False
# 119                PMI                       CDS                  False
# 120                AMR                       CDS                  False
# 121           Seat-A05                      LCDS                  False
# 122              NRAMC              CDS-Bucket-1                   True
# 123              NRAMC              CDS-Bucket-2                   True
# 124                 EK                       CDS                  False
# 125             GREECE                       CDS                  False
# 126      HITACH-Elpida                       CDS                  False
# 127              FCGIA                      LCDS                  False
# 128             ERCIFT                       CDS                  False
# 129       HAWKER-Acqui                      LCDS                  False
# 130       ELCDS-Eircom                LCDS-LIEN1                   True
# 131       ELCDS-Eircom                LCDS-LIEN2                   True
# 132               SIFO                       CDS                  False
# 133             HTNMIF                       CDS                  False
# 134         GM-ResCLLC                       CDS                  False
# 135         ELCDS-Yell                LCDS-LIEN1                  False
# 136                OSG                       CDS                  False
# 137    EIX-EdMisEnergy                       CDS                  False
# 138           PJHOLDCO                      LCDS                  False
# 139             SNSBNK            CDS-SNR-or-SUB                   True
# 140             SNSBNK   CDS-SNR-or-SUB-Bucket-1                   True
# 141               DXMI                      LCDS                  False
# 142               SPMD                      LCDS                  False
# 143             BANKSA            CDS-SNR-or-SUB                   True
# 144             BANKSA   CDS-SNR-or-SUB-Bucket-1                   True
# 145             BANKSA   CDS-SNR-or-SUB-Bucket-2                   True
# 146             BANKSA   CDS-SNR-or-SUB-Bucket-3                   True
# 147             URBISA                       CDS                  False
# 148             CENGLQ                      LCDS                  False
# 149          CODSA-Fin                       CDS                  False
# 150             OGXPET                       CDS                  False
# 151            ENERFUT                       CDS                  False
# 152            ENERGFU                       CDS                  False
# 153     TXU-Texas-LCDS                LCDS-LIEN1                  False
# 154          TXU-Texas                       CDS                  False
# 155            SOLOGRO                      LCDS                  False
# 156             ARGENT                       CDS                  False
# 157             CESEOP                       CDS                   True
# 158             CESEOP                      LCDS                   True
# 159                RSH                       CDS                  False
# 160            SABINOI                       CDS                  False
# 161               AAHI                       CDS                  False
# 162             UKRAIN                       CDS                  False
# 163               ABNG                       CDS                  False
# 164            PACIEXP                       CDS                  False
# 165             PLCOAL                       CDS                  False
# 166              NSINO                       CDS                   True
# 167              NSINO                CDS-Bucket                   True
# 168              NSINO              CDS-Bucket-3                   True
# 169              NSINO              CDS-Bucket-4                   True
# 170      PLTMPL-IntFin                       CDS                  False
# 171             CMNWPR                       CDS                  False
# 172            GRUPOIS                       CDS                  False
# 173            IHEAINC                       CDS                   True
# 174            IHEAINC                      LCDS                   True
# 175                 AV                      LCDS                  False
# 176            GENOENE                       CDS                  False
# 177              PREPA                       CDS                  False
# 178              NSINO                       CDS                   True
# 179              NSINO                CDS-Bucket                   True
# 180              NSINO              CDS-Bucket-3                   True
# 181              NSINO              CDS-Bucket-4                   True
# 182              MONTE                  CDS-2014                  False
# 183              BPESP         CDS-2003-Bucket-1                   True
# 184              BPESP         CDS-2003-Bucket-2                   True
# 185               TOYS                      LCDS                  False
# 186                TOY                CDS-Senior                  False
# 187              MONTE         CDS-2003-Bucket-1                   True
# 188              MONTE         CDS-2003-Bucket-2                   True
# 189               VENZ                       CDS                  False
# 190                PDV                       CDS                  False
# 191              NBLGP                       CDS                  False
# 192            NINEWES                       CDS                  False
# 193            NOVOBAN                CDS-Bucket                  False
# 194              BPESP           CDS-Subordinate                  False
# 195            NOVOBAN                CDS-Senior                  False
# 196               ASTL                       CDS                  False
# 197     SHC-Acceptance                       CDS                  False
# 198                PKD                       CDS                  False
# 199      PCGPacGasElec                       CDS                  False
# 200            WINDSSE                       CDS                  False
# 201           NEWLOOAC                       CDS                  False
# 202               GENP                       CDS                  False
# 203                WFT                CDS-Senior                  False
# 204            GALAPHO                       CDS                  False
# 205              TOGUN                CDS-Senior                  False
# 206            STEIEUR                       CDS                  False
# 207               THCP                CDS-Senior                  False
# 208             DNSFDS                       CDS                  False
# 209             MCLTHY                       CDS                  False
# 210              LEBAN                       CDS                  False
# 211              WHPEC                CDS-Senior                  False
# 212               FRCA                CDS-Senior                  False
# 213               ECUA                       CDS                  False
# 214                 DO                CDS-Senior                  False
# 215             THENEI                       CDS                  False
# 216             INTINV                       CDS                  False
# 217                JCP                CDS-Senior                  False
# 218             ARGENT                       CDS                  False
# 219            F-Hertz                       CDS                  False
# 220            CALIRES                       CDS                  False
# 221             WIREAG                       CDS                  False
# 222                CHK                       CDS                  False
# 223            HEMABON                       CDS                  False
# 224                 NE                       CDS                  False
# 225            MATAFIN                       CDS                  False
# 226            PIZZAFI                       CDS                  False
# 227            SELEGRO                       CDS                  False
# 228            EUROPMO                       CDS                  False
# 229            TALEENE                       CDS                  False
# 230             RUSSIA                       CDS                  False
# 231             UKRAIN                       CDS                  False
# 232            DIAMSPO                       CDS                  False
#
#      final_price      IMM                           NOI  noi_absolute_value  \
# 0         63.375   66.000           $99 million to sell        9.900000e+07
# 1         19.125   20.000           $45 million to sell        4.500000e+07
# ...
# 28             1.0      USD           1.0             USD/USD  1.296155e+07
# 29            -1.0      EUR      0.779484             USD/EUR  2.565800e+06
# 30             0.0      EUR      0.779484             USD/EUR  0.000000e+00
# 31             1.0      GBP      0.669588             USD/GBP  1.642801e+07
# 32             0.0      GBP      0.669588             USD/GBP  0.000000e+00
# 33             1.0      USD           1.0             USD/USD  4.338041e+08
# 34             1.0      USD           1.0             USD/USD  1.928948e+07
# 35             1.0      USD           1.0             USD/USD  1.921704e+08
# 36             1.0      USD           1.0             USD/USD  5.973823e+07
# 37             0.0      EUR       0.78235             USD/EUR  0.000000e+00
# 38            -1.0      USD           1.0             USD/USD  5.112800e+07
# 39            -1.0      USD           1.0             USD/USD  3.067680e+07
# 40             1.0      USD           1.0             USD/USD  1.262069e+08
# 41             1.0      USD           1.0             USD/USD  1.669738e+08
# 42             1.0      USD           1.0             USD/USD  1.097335e+07
# 43             1.0      EUR      0.757805             USD/EUR  1.256853e+08
# 44             1.0      USD           1.0             USD/USD  3.091123e+08
# 45             1.0      USD           1.0             USD/USD  6.492432e+07
# 46             1.0      USD           1.0             USD/USD  5.278400e+07
# 47             1.0      USD           1.0             USD/USD  1.518200e+08
# 48             1.0      USD           1.0             USD/USD  1.173859e+09
# 49             1.0      USD           1.0             USD/USD  1.319600e+07
# 50             1.0      USD           1.0             USD/USD  1.551625e+08
# 51             1.0      USD           1.0             USD/USD  2.639200e+07
# 52            -1.0      USD           1.0             USD/USD  3.100057e+08
# 53             0.0      EUR      0.721709             USD/EUR  0.000000e+00
# 54             1.0      USD           1.0             USD/USD  9.699200e+06
# 55            -1.0      USD           1.0             USD/USD  2.216960e+07
# 56             1.0      USD           1.0             USD/USD  1.120950e+09
# 57             1.0      USD           1.0             USD/USD  1.993878e+08
# 58            -1.0      USD           1.0             USD/USD  7.331182e+08
# 59             1.0      USD           1.0             USD/USD  6.373760e+07
# 60            -1.0      USD           1.0             USD/USD  3.879680e+07
# 61             1.0      USD           1.0             USD/USD  2.489605e+08
# 62             1.0      USD           1.0             USD/USD  5.542400e+07
# 63             1.0      USD           1.0             USD/USD  2.355520e+07
# 64             1.0      USD           1.0             USD/USD  1.801280e+07
# 65             1.0      USD           1.0             USD/USD  5.126720e+07
# 66            -1.0      USD           1.0             USD/USD  8.590720e+07
# 67             1.0      USD           1.0             USD/USD  2.632640e+07
# 68             1.0      USD           1.0             USD/USD  2.390548e+08
# 69             1.0      USD           1.0             USD/USD  9.699200e+07
# 70            -1.0      EUR      0.711592             USD/EUR  2.042379e+08
# 71             1.0      EUR      0.711592             USD/EUR  3.888465e+07
# 72             0.0      GBP       0.62318             USD/GBP  0.000000e+00
# 73             1.0      EUR      0.666667             USD/EUR  1.214505e+08
# 74             1.0      EUR      0.666667             USD/EUR  3.310035e+08
# 75             1.0      EUR      0.666667             USD/EUR  2.213520e+08
# 76             1.0      USD             1             USD/USD  3.450000e+07
# 77             1.0      USD             1             USD/USD  1.093470e+09
# 78             1.0      EUR      0.678887             USD/EUR  8.469014e+07
# 79             1.0      EUR      0.687711             USD/EUR  3.580619e+08
# 80             1.0      USD             1             USD/USD  1.972414e+08
# 81            -1.0      USD             1             USD/USD  2.650170e+08
# 82            -1.0      USD             1             USD/USD  1.314870e+08
# 83             1.0      JPY     92.422881             USD/JPY  1.839371e+05
# 84            -1.0      GBP      0.647778             USD/GBP  0.000000e+00
# 85             1.0      JPY     92.982982             USD/JPY  3.226397e+06
# 86             1.0      USD             1             USD/USD  3.227451e+06
# 87             1.0      EUR      0.779545             USD/EUR  3.017954e+08
# 88             0.0      EUR      0.786473             USD/EUR  0.000000e+00
# 89            -1.0      USD             1             USD/USD  6.357500e+06
# 90             1.0      JPY      81.23692             USD/JPY  2.609651e+08
# 91             1.0      EUR      0.756773             USD/EUR  1.374917e+08
# 92             1.0      EUR      0.756773             USD/EUR  3.105290e+07
# 93            -1.0      EUR      0.756773             USD/EUR  2.979757e+07
# 94             1.0      EUR      0.756773             USD/EUR  1.486575e+07
# 95             1.0      EUR      0.756773             USD/EUR  3.964200e+07
# 96             1.0      USD             1             USD/USD  5.390057e+08
# 97            -1.0      EUR       0.72448             USD/EUR  1.090437e+07
# 98            -1.0      EUR      0.691898             USD/EUR  2.962865e+06
# 99            -1.0      EUR      0.691898             USD/EUR  3.273605e+07
# 100           -1.0      EUR      0.701262             USD/EUR  4.420600e+07
# 101            1.0      EUR      0.701262             USD/EUR  1.825280e+07
# 102           -1.0      EUR      0.701262             USD/EUR  7.343900e+06
# 103            NaN      EUR      0.701262             USD/EUR           NaN
# 104            1.0      EUR      0.701262             USD/EUR  4.278000e+06
# 105           -1.0      EUR      0.701262             USD/EUR  3.992800e+07
# 106           -1.0      EUR      0.701262             USD/EUR  4.278000e+06
# 107           -1.0      EUR      0.701262             USD/EUR  3.565000e+07
# 108            1.0      EUR      0.701262             USD/EUR  1.654160e+07
# 109           -1.0      EUR      0.701262             USD/EUR  1.426000e+07
# 110            1.0      EUR      0.701262             USD/EUR  1.639900e+07
# 111            NaN      EUR      0.701262             USD/EUR           NaN
# 112            1.0      EUR      0.701262             USD/EUR  7.130000e+06
# 113            NaN      EUR      0.749794             USD/EUR           NaN
# 114           -1.0      EUR      0.749794             USD/EUR  1.333700e+07
# 115            1.0      JPY     77.723172             USD/JPY  3.087882e+07
# 116            NaN      EUR      0.746993             USD/EUR           NaN
# 117           -1.0      USD             1             USD/USD  8.186954e+07
# 118            1.0      EUR      0.747161             USD/EUR  8.933820e+07
# 119            1.0      USD             1             USD/USD  5.026870e+08
# 120           -1.0      USD             1             USD/USD  1.599187e+08
# 121            1.0      EUR      0.781861             USD/EUR  1.745707e+07
# 122           -1.0      EUR      0.763709             USD/EUR  2.291450e+07
# 123           -1.0      EUR      0.763709             USD/EUR  1.440340e+07
# 124            1.0      USD             1             USD/USD  2.964076e+08
# 125            1.0      EUR      0.760456             USD/EUR  3.834540e+08
# 126            1.0      JPY     83.086504             USD/JPY  2.166417e+07
# 127           -1.0      EUR      0.749794             USD/EUR  6.668500e+06
# 128            1.0      EUR      0.753466             USD/EUR  1.636438e+08
# 129           -1.0      USD             1             USD/USD  3.981600e+06
# 130            1.0      EUR      0.761557             USD/EUR  5.121090e+07
# 131           -1.0      EUR      0.761557             USD/EUR  1.313100e+06
# 132            1.0      USD             1             USD/USD  4.733725e+07
# 133            1.0      USD             1             USD/USD  2.122626e+07
# 134           -1.0      USD             1             USD/USD  3.812192e+07
# 135           -1.0      EUR      0.783945             USD/EUR  2.359860e+07
# 136            1.0      USD             1             USD/USD  5.253559e+07
# 137           -1.0      USD             1             USD/USD  7.972500e+06
# 138           -1.0      EUR      0.738007             USD/EUR  2.710000e+06
# 139            1.0      EUR      0.780153             USD/EUR  1.493297e+07
# 140            1.0      EUR      0.780153             USD/EUR  1.666340e+07
# 141           -1.0      USD           1.0             USD/USD  2.563600e+06
# 142           -1.0      USD           1.0             USD/USD  2.563600e+06
# 143           -1.0      EUR      0.765287             USD/EUR  2.744070e+07
# 144           -1.0      EUR      0.765287             USD/EUR  1.659509e+07
# 145            1.0      EUR      0.765287             USD/EUR  9.800250e+06
# 146            1.0      EUR      0.765287             USD/EUR  1.306700e+07
# 147            1.0      USD             1             USD/USD  9.525843e+07
# 148            0.0      USD             1             USD/USD  0.000000e+00
# 149           -1.0      EUR      0.739919             USD/EUR  1.398127e+08
# 150           -1.0      USD             1             USD/USD  2.703000e+05
# 151            0.0      USD           1.0             USD/USD  0.000000e+00
# 152           -1.0      USD             1             USD/USD  3.236032e+07
# 153           -1.0      USD             1             USD/USD  1.905615e+08
# 154            1.0      USD             1             USD/USD  9.561862e+07
# 155           -1.0      EUR      0.748839             USD/EUR  6.677000e+05
# 156           -1.0      USD             1             USD/USD  1.282385e+08
# 157            1.0      USD             1             USD/USD  6.556013e+07
# 158           -1.0      USD             1             USD/USD  4.940980e+07
# 159            1.0      USD             1             USD/USD  7.921326e+07
# 160            1.0      USD             1             USD/USD  6.254079e+07
# 161            1.0      USD             1             USD/USD  6.361579e+07
# 162            1.0      USD             1             USD/USD  2.063193e+07
# 163            1.0      EUR      0.918021             USD/EUR  3.588154e+08
# 164            1.0      USD             1             USD/USD  1.339839e+06
# 165            1.0      USD           1.0             USD/USD  7.109534e+07
# 166            1.0      EUR      0.886289             USD/EUR  7.813478e+07
# 167            1.0      EUR      0.886289             USD/EUR  3.847503e+07
# 168            0.0      EUR      0.886289             USD/EUR  0.000000e+00
# 169            1.0      EUR      0.886289             USD/EUR  6.262065e+06
# 170            1.0      EUR      0.907853             USD/EUR  9.494930e+07
# 171           -1.0      USD             1             USD/USD  9.103898e+06
# 172            1.0      EUR      0.887469             USD/EUR  6.411492e+07
# 173            1.0      USD             1             USD/USD  2.050573e+08
# 174            0.0      USD             1             USD/USD  0.000000e+00
# 175           -1.0      USD           1.0             USD/USD  0.000000e+00
# 176            1.0      USD             1             USD/USD  7.189547e+07
# 177            1.0      USD             1             USD/USD  4.326912e+06
# 178            1.0      EUR      0.841397             USD/EUR  8.230362e+07
# 179            1.0      EUR      0.841397             USD/EUR  4.052785e+07
# 180            0.0      EUR      0.841397             USD/EUR  0.000000e+00
# 181            1.0      EUR      0.841397             USD/EUR  6.596175e+06
# 182           -1.0      EUR      0.839983             USD/EUR  3.511975e+06
# 183           -1.0      EUR      0.851644             USD/EUR  1.174200e+07
# 184            0.0      EUR      0.851644             USD/EUR  0.000000e+00
# 185           -1.0      USD             1             USD/USD  0.000000e+00
# 186            1.0      USD             1             USD/USD  9.531216e+07
# 187           -1.0      EUR      0.861178             USD/EUR  6.392406e+07
# 188            1.0      EUR      0.861178             USD/EUR  6.386600e+06
# 189           -1.0      USD             1             USD/USD  1.220804e+08
# 190            1.0      USD             1             USD/USD  1.229943e+08
# 191            1.0      USD             1             USD/USD  7.315560e+06
# 192            1.0      USD             1             USD/USD  1.885220e+08
# 193           -1.0      EUR      0.832848             USD/EUR  0.000000e+00
# 194            NaN      EUR       0.85955             USD/EUR           NaN
# 195            NaN      EUR      0.882768             USD/EUR           NaN
# 196           -1.0      EUR      0.878194             USD/EUR  4.258738e+07
# 197           -1.0      USD             1             USD/USD  5.116862e+07
# 198            1.0      USD             1             USD/USD  5.397096e+07
# 199            1.0      USD             1             USD/USD  2.368496e+07
# 200           -1.0      USD             1             USD/USD  7.766389e+07
# 201            1.0      EUR      0.888336             USD/EUR  6.619116e+07
# 202            1.0      EUR      0.879507             USD/EUR  1.900496e+08
# 203            1.0      USD             1             USD/USD  1.060957e+08
# 204            1.0      EUR      0.892698             USD/EUR  1.613088e+07
# 205           -1.0      EUR      0.908843             USD/EUR  0.000000e+00
# 206           -1.0      EUR      0.910581             USD/EUR  9.224880e+06
# 207            1.0      EUR      0.900414             USD/EUR  1.906900e+08
# 208            1.0      USD             1             USD/USD  2.010031e+08
# 209            1.0      USD             1             USD/USD  6.948247e+07
# 210            1.0      USD             1             USD/USD  1.207222e+08
# 211            1.0      USD             1             USD/USD  2.140937e+08
# 212            1.0      USD             1             USD/USD  1.295304e+08
# 213           -1.0      USD             1             USD/USD  3.029939e+07
# 214            1.0      USD             1             USD/USD  1.961153e+08
# 215            1.0      USD             1             USD/USD  1.984764e+08
# 216           -1.0      USD             1             USD/USD  0.000000e+00
# 217            1.0      USD             1             USD/USD  3.910611e+08
# 218            1.0      USD             1             USD/USD  3.452700e+08
# 219            1.0      USD             1             USD/USD  1.238597e+08
# 220            1.0      USD             1             USD/USD  7.667916e+07
# 221            1.0      EUR      0.852878             USD/EUR  5.874225e+07
# 222            1.0      USD             1             USD/USD  3.114465e+08
# 223            1.0      EUR      0.848536             USD/EUR  5.185400e+06
# 224            1.0      USD             1             USD/USD  1.315029e+08
# 225            1.0      GBP      0.774428             USD/GBP  1.484967e+07
# 226            1.0      GBP      0.771979             USD/GBP  6.185400e+07
# 227            1.0      EUR       0.84674             USD/EUR  9.211800e+06
# 228           -1.0      EUR      0.821963             USD/EUR  5.267878e+07
# 229           -1.0      USD             1             USD/USD  1.290180e+08
# 230           -1.0      USD             1             USD/USD  6.112198e+08
# 231           -1.0      USD             1             USD/USD  4.988060e+07
# 232            1.0      USD             1             USD/USD  5.438202e+07

# %%
unique_currencies = data['currency'].unique()
print(unique_currencies)
# Out:
# ['USD' 'EUR' 'GBP' 'JPY']

# %%
currency_values = [ '.']
mask = data['currency'].isin(currency_values)
identifiers = data.loc[mask, 'identifier'].tolist()
print(identifiers)
# Out:
# []

# %%
# Specify the file path and name for saving the updated DataFrame
output_folder = "../../data/final_database"
os.makedirs(output_folder, exist_ok=True)
output_csv = os.path.join(output_folder, "auctions_main_updated.csv")

# Save the updated DataFrame as CSV
data.to_csv(output_csv, index=False)
print(f"Updated DataFrame saved as: {output_csv}")
# Out:
# Updated DataFrame saved as: ../../data/final_database/auctions_main_updated.csv
